# %% [markdown]
# # LDA using BOW & TF-IDF with introduction of bi-grams & tri-grams

# %%
Objective : To determine the latent topics as anchors for the model.

Conclusion: Topic modelling using LDA after fine tuning using cross validation grid search obtained topic coherence of about - 0.53  

Approach : Pre-processing steps - 
1) noisy data removal - date , ,aonth, CSCDD, names etc using regex pattern
2) Stop words removal
3) Punctuation marks removal
4) creation additional bi grams & tri grams
5) lemmatization
6) creating corpus and dictionary
7) training lda model
8) fine tuning the model using cross validation grid serach.

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import nltk
import re
import string
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize 
import re
import pandas as pd
# Gensim
import gensim
import gensim.corpora as corpora
from gensim.utils import simple_preprocess
from gensim.models import CoherenceModel
from pprint import pprint
import matplotlib.pyplot as plt
import seaborn as sns
import nltk
import re
import string
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize 
import pandas as pd
import pickle
# pd.set_options("display.max_colwidth","None")
pd.set_option('display.max_colwidth', 1000)
import warnings
warnings.filterwarnings("ignore",category=DeprecationWarning)

# %%
import calendar
cal=list(calendar.month_name)
for i in list(calendar.month_name[1:]):
    cal.append(i[:3])

# %%
# # Plotting tools
# import pyLDAvis
# import pyLDAvis.gensim_models as gensimvis  

import warnings
# warnings.filterwarnings("ignore",category=DeprecationWarning)

# %% [markdown]
#  ##Topic Modelling:
# Topic modeling is an unsupervised learning technique used to extract topics from a large corpus of text automatically. Topics can be defined as the co-occurring terms that are frequently repeating in the text corpus. Topic modeling is helpful in various tasks such as clustering documents, understanding and summarizing an extensive collection of textual documents and retrieving information from an extensive collection of data, etc. In this notebook I will perform topic modelling using LDA(Latent Dirichlet Allocation) and BERT.
#
# Here I am using medium article dataset to perfom Topic Modelling. The dataset consist 350 articles related to AI, Machine Learning and Data Science.

# %% [markdown]
# ## Exploring the dataset :

# %%
df_all_comments = pd.read_csv("generated_all_value_count_comments.csv")
df_all_comments.drop(columns="Unnamed: 0",axis=1,inplace=True)
df_all_comments.head()

# %% [markdown]
# ## Exploration of text Data

# %% [markdown]
# Removing special characters
#
# 1.re.sub("\n","",x)-line change character to be discarded
# 2.re.sub("Name – Name","Name",x)
# 3.re.sub("Name_Name","Name",x)
# 4. _ with ""
# 5 - with ""
#
# omitting technical values of anchors
# 1. omitting date of birth
# 2. omitting most common names
# 3. omitting id values
# 4. omitting false-hit| true-hit
# 3.Unknown|false hit|False Hit.|False Hit|True Hit|True Hit.|Rationale|Source -omit them
# omitting Mohd,NORAINI,ABDULLAH,BINTI,system, legal , stated , ABD
# 4 Numbers
#
#
#
# Removing useless comments
#
# 1.drop - Match ID and/or Full Legal Name (doubtfull)
# 2.Agreed with analyst recommendation|Agreed with analyst's recommendation|Agreed as per Maker comment|Agreed as per Maker's comment|AGREED WITH MAKER RECOMMENDATION|Agreed With Maker Comments - replace with substring
#
# 4.CSCDD7|CSCDD4 - Remove comments
# 5CSCDD1 - remove ( still doubtful )
# 6 SCC6|No further review is required by analyst - remove comment
# 7 SC Status : No further review is required by analyst - remove comment
# 8 SC/DEL -remove
#
# 15 URL removal like - https://edmsfilenet.maybank.com.my/WorkplaceBFE/WcmSignIn.jsp?targetBase=https%3A%2F%2Fedmsfilenet.maybank.com.my%2FWorkplaceBFE&originPort=&originIp=172.31.75.67&targetUrl=WcmDefault.jsp
# special characters - Mismatch Full Legal Name â€“ Name Does Not Sound Similar ,
# 16 Not removing any special character for now - Mismatch Full Legal Name_Name does not sound similar - watchperson Zhang Ping 张平 vs customer Zhang Peng 张鹏

# %%
patt6=re.compile("https?://\S+|www\.\S+",re.IGNORECASE)
# df_all_comments[df_all_comments["V_COMMENTS"].apply(lambda x: len(re.findall(patt6,x))>0)]
ind=df_all_comments[df_all_comments["V_COMMENTS"].str.extract(r"(https?://\S+|www\.\S+)")[0].apply(lambda x: pd.notna(x))].index
df_all_comments.loc[ind,"V_COMMENTS"].str.extract(r"(https?://.*\.com|www\..*\.com)").value_counts().to_csv("URL_in_comments.csv")
#

# %% [markdown]
# # Pre-processing on Data

# %% [markdown]
# ### Step -1 removing noisy data

# %%
patt1=re.compile("Match ID and/or Full Legal Name",re.IGNORECASE)
# patt2=re.compile("Agreed with analyst recommendation|Agreed with analyst's recommendation|Agreed as per Maker comment|Agreed as per Maker's comment")
patt2=re.compile("(Agreed|agree) (to|with|as per) (analyst(('s)*)|maker(('s)*)) (comment|recommendation|is recommendation)",re.IGNORECASE)
patt3=re.compile("Unknown|false hit\.*|true hit\.*|Rationale|Source",re.IGNORECASE)
patt4=re.compile("CSCDD7|CSCDD1|CSCDD4",re.IGNORECASE)
patt5=re.compile("SCC6|No further review is required by analyst|SC/DEL",re.IGNORECASE)
patt6=re.compile("https?://\S+|www\.\S+",re.IGNORECASE)
patt7=re.compile("(%s)"%"|".join(cal)[1:],re.IGNORECASE)
patt8=re.compile("\s*(Mohd|NORAINI|ABDULLAH|BINTI|system|legal|stated|ABD|mahdzir|bin|khalid|siti|hajar|mohd|sallehudin|mohd|saddam|inie|binti|abdullah|noraini|norliza|binti|othman)\s*",re.IGNORECASE)

# %%
df_all_comments["V_COMMENTS_2"]=df_all_comments["V_COMMENTS"].apply(lambda x: re.sub("\n"," ",x)) #1

df_all_comments["V_COMMENTS_2"]=df_all_comments["V_COMMENTS_2"].apply(lambda x: re.sub("Name – Name","Name",x))    #2                                
df_all_comments["V_COMMENTS_2"]=df_all_comments["V_COMMENTS_2"].apply(lambda x: re.sub("Name_Name","Name",x))      #3                              
df_all_comments["V_COMMENTS_2"]=df_all_comments["V_COMMENTS_2"].apply(lambda x: re.sub("\s*_\s*|\s*-\s*|\s*,\s*"," ",x)) #4,5


df_all_comments=df_all_comments[df_all_comments["V_COMMENTS_2"].str.contains(patt1)==False] #7
df_all_comments["V_COMMENTS_2"]=df_all_comments["V_COMMENTS_2"].apply(lambda x: re.sub(patt2,"",x)) #8
df_all_comments["V_COMMENTS_2"]=df_all_comments["V_COMMENTS_2"].apply(lambda x: re.sub(patt3,"",x))  #  9
df_all_comments=df_all_comments[df_all_comments["V_COMMENTS_2"].str.contains(patt4)==False]        # 10
df_all_comments=df_all_comments[df_all_comments["V_COMMENTS_2"].str.contains(patt5)==False]       #11
df_all_comments["V_COMMENTS_2"]=df_all_comments["V_COMMENTS_2"].apply(lambda x: re.sub(patt6,"",x)) #15
df_all_comments["V_COMMENTS_2"]=df_all_comments["V_COMMENTS_2"].apply(lambda x: re.sub("[^\w\s\.]|\d","",x)) 
df_all_comments["V_COMMENTS_2"]=df_all_comments["V_COMMENTS_2"].apply(lambda x: re.sub("\d*","",x))    #date, year, accounts 6
df_all_comments["V_COMMENTS_2"]=df_all_comments["V_COMMENTS_2"].apply(lambda x: re.sub(patt7,"",x))    # month 6
df_all_comments["V_COMMENTS_2"]=df_all_comments["V_COMMENTS_2"].apply(lambda x: re.sub(patt8," ",x)) # 17

# %%
df_all_comments["V_COMMENTS_2"]=df_all_comments["V_COMMENTS_2"].str.lower()

# %%
df_all_comments_org=df_all_comments.copy()
df_all_comments_org.to_csv("Stage_1_comments_after_pre_process_bigram_trigram.csv")

# %%
# Agreed with analyst recommendation|Agreed with analyst's recommendation|Agreed as per Maker comment|Agreed as per Maker's comment

# %%
# re.sub("Agreed with(a*) recommendation","","Agreed with recommendation")
# re.sub("Agreed (with|as per) recommendation","","Agreed recommendation")
patt=re.compile("Agreed (with|as per) (analyst(('s)*)|maker(('s)*)) (comment|recommendation)",re.IGNORECASE)
re.escape("analyst's")

# %%
df_all_comments=pd.read_csv("Stage_1_comments_after_pre_process_bigram_trigram.csv")

# %%
# x=re.compile("false hit\.*",re.IGNORECASE)
# re.findall(x,"false Hit.")
# txt="https://edmsfilenet.maybank.com.my/WorkplaceBFE/WcmSignIn.jsp?targetBase=https%3A%2F%2Fedmsfilenet.maybank.com.my%2FWorkplaceBFE&originPort=&originIp=172.31.75.67&targetUrl=WcmDefault.jsp"

# re.findall("https?://\S+|www\.\S+",txt)

# %%
# df_all_comments[df_all_comments["V_COMMENTS"].str.contains("Mismatch Full Legal Name_Name does not sound similar - watchperson")].head(1)["V_COMMENTS"]

# %%
df_all_comments["V_COMMENTS_2"]
# Out:
# 0                                                                                                                                                                                                                                                                                                                                                                 mismatch id number nric
# 1                                                                                                                                                                                                                                                                                                                                                                mismatch id number nric
# 2                                                                                                                                                                                                                                                                                                                                                              mismatch year of birth yob
# 3                                                                                                                                                                                                                                                                                                                                                                 mismatch id number nric
# 4                                                                                                                                                                                                                                                                                                                                               mismatch full name does not sound similar
#                                                                                                                                                                                                ...
# 221574                                                           mismatch name nric date of birth profile customer  name   nric    date of birth   profile  shop sales assistants at monaliza  mastura sb computer st as per host watch person as per host based on customer number  name    nric   date of birth    profile  pep related  pep spouse. mahani dhter.  dhter.  son.   son.
# 221575                                                                               mismatch name nric date of birth profile customer as per host name   nric    date of birth   profile  is a housewifehousehusband as per host watch person as per host based on customer number  name    nric   date of birth    profile  pep related  pep spouse. mahani dhter.  dhter.  son.   son.
# 221576                                                                                                                                                                                                                                           mismatch id number nric. watch person    is a bank customer with nric  gcif .  pep has transaction with her on apex . customers nric is
# 221577                                                                                                                                                                                                                                           mismatch id number nric. watch person    is a bank customer with nric  gcif .  pep has transaction with her on apex . customers nric is
# 221578    mismatch profile as adverse news reported   detained by punjab police in patiala for alleged involvement in planning of terror acts and target killings. case registered under the unlawful activities prevention act.   no further information reported apex account customer shows an active transaction since  . hence it is highly unlikely that watchperson is a customer.
# Name: V_COMMENTS_2, Length: 221579, dtype: object

# %%
df_all_comments["V_COMMENTS_2"]=df_all_comments["V_COMMENTS_2"].apply(lambda x : "" if pd.isna(x) else x)

# %%
df_all_comments=df_all_comments[df_all_comments["V_COMMENTS_2"].apply(lambda x : len(x)!=0)]

# %%
#lowercase the articles 
df_all_comments.V_COMMENTS = df_all_comments.V_COMMENTS.apply(lambda t : t.lower())

# %% [markdown]
# Need to check whether to remove top x count words and last y count words

# %% [markdown]
# **Expanding contractions:** Contractions are the shortened form of the words like it's, hasn't. We expand them for better analysis of our V_COMMENTS data. I have taken these contractions from [Analytics Vidhay's article](http://https://www.analyticsvidhya.com/blog/2020/04/beginners-guide-exploratory-data-analysis-V_COMMENTS-data/).

# %%
# Dictionary of English Contractions
contractions_dict = { "ain't": "are not","'s":" is","aren't": "are not",
                     "can't": "cannot","can't've": "cannot have",
                     "'cause": "because","could've": "could have","couldn't": "could not",
                     "couldn't've": "could not have", "didn't": "did not","doesn't": "does not",
                     "don't": "do not","hadn't": "had not","hadn't've": "had not have",
                     "hasn't": "has not","haven't": "have not","he'd": "he would",
                     "he'd've": "he would have","he'll": "he will", "he'll've": "he will have",
                     "how'd": "how did","how'd'y": "how do you","how'll": "how will",
                     "I'd": "I would", "I'd've": "I would have","I'll": "I will",
                     "I'll've": "I will have","I'm": "I am","I've": "I have", "isn't": "is not",
                     "it'd": "it would","it'd've": "it would have","it'll": "it will",
                     "it'll've": "it will have", "let's": "let us","ma'am": "madam",
                     "mayn't": "may not","might've": "might have","mightn't": "might not", 
                     "mightn't've": "might not have","must've": "must have","mustn't": "must not",
                     "mustn't've": "must not have", "needn't": "need not",
                     "needn't've": "need not have","o'clock": "of the clock","oughtn't": "ought not",
                     "oughtn't've": "ought not have","shan't": "shall not","sha'n't": "shall not",
                     "shan't've": "shall not have","she'd": "she would","she'd've": "she would have",
                     "she'll": "she will", "she'll've": "she will have","should've": "should have",
                     "shouldn't": "should not", "shouldn't've": "should not have","so've": "so have",
                     "that'd": "that would","that'd've": "that would have", "there'd": "there would",
                     "there'd've": "there would have", "they'd": "they would",
                     "they'd've": "they would have","they'll": "they will",
                     "they'll've": "they will have", "they're": "they are","they've": "they have",
                     "to've": "to have","wasn't": "was not","we'd": "we would",
                     "we'd've": "we would have","we'll": "we will","we'll've": "we will have",
                     "we're": "we are","we've": "we have", "weren't": "were not","what'll": "what will",
                     "what'll've": "what will have","what're": "what are", "what've": "what have",
                     "when've": "when have","where'd": "where did", "where've": "where have",
                     "who'll": "who will","who'll've": "who will have","who've": "who have",
                     "why've": "why have","will've": "will have","won't": "will not",
                     "won't've": "will not have", "would've": "would have","wouldn't": "would not",
                     "wouldn't've": "would not have","y'all": "you all", "y'all'd": "you all would",
                     "y'all'd've": "you all would have","y'all're": "you all are",
                     "y'all've": "you all have", "you'd": "you would","you'd've": "you would have",
                     "you'll": "you will","you'll've": "you will have", "you're": "you are",
                     "you've": "you have"}

# %%
# Regular expression for finding contractions
contractions_re=re.compile('(%s)' % '|'.join(contractions_dict.keys()))
contractions_re
# Out:
# re.compile(r"(ain't|'s|aren't|can't|can't've|'cause|could've|couldn't|couldn't've|didn't|doesn't|don't|hadn't|hadn't've|hasn't|haven't|he'd|he'd've|he'll|he'll've|how'd|how'd'y|how'll|I'd|I'd've|I'll|I'll've|I'm|I've|isn't|it'd|it'd've|it'll|it'll've|let's|ma'am|mayn't|might've|mightn't|mightn't've|must've|mustn't|mustn't've|needn't|needn't've|o'clock|oughtn't|oughtn't've|shan't|sha'n't|shan't've|she'd|she'd've|she'll|she'll've|should've|shouldn't|shouldn't've|so've|that'd|that'd've|there'd|there'd've|they'd|they'd've|they'll|they'll've|they're|they've|to've|wasn't|we'd|we'd've|we'll|we'll've|we're|we've|weren't|what'll|what'll've|what're|what've|when've|where'd|where've|who'll|who'll've|who've|why've|will've|won't|won't've|would've|wouldn't|wouldn't've|y'all|y'all'd|y'all'd've|y'all're|y'all've|you'd|you'd've|you'll|you'll've|you're|you've)",
# re.UNICODE)

# %% [markdown]
# ### Step-2 expanding contractions

# %%
# Function for expanding contractions
def expand_contractions(V_COMMENTS,contractions_dict=contractions_dict):
    def replace(match):
        return contractions_dict[match.group(0)]
    return contractions_re.sub(replace, V_COMMENTS)

# Expanding Contractions in the V_COMMENTS data
df_all_comments.V_COMMENTS = df_all_comments.V_COMMENTS.apply(lambda x:expand_contractions(x))

# %% [markdown]
# ### step -3 removing stopwords after tokenizing using word_tokenize

# %% [markdown]
# **Removing Stopwords and Puctuations**: Stopwords are the words that are highly occurred in a language; they do not add any significance to the sentence. "a," "an," "the," "in" are some examples of stopwords. So we generally ignore stop words during our NLP task. In some NLP tasks, stop words are also important, but stopwords are unnecessary for topic modeling. We also remove punctuation marks because they are also unnecessary and do not contribute anything.

# %%
print(stopwords.words('english'))
# Out:
# ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', "you're", "you've", "you'll", "you'd", 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', "she's", 'her', 'hers', 'herself', 'it', "it's", 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', "that'll", 'these', 'those', 'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 'no', 'nor', 'not', 'only', 'own', 'same', 'so', 'than', 'too', 'very', 's', 't', 'can', 'will', 'just', 'don', "don't", 'should', "should've", 'now', 'd', 'll', 'm', 'o', 're', 've', 'y', 'ain', 'aren', "aren't", 'couldn', "couldn't", 'didn', "didn't", 'doesn', "doesn't", 'hadn', "hadn't", 'hasn', "hasn't", 'haven', "haven't", 'isn', "isn't", 'ma', 'mightn', "mightn't", 'mustn', "mustn't", 'needn', "needn't", 'shan', "shan't", 'shouldn', "shouldn't", 'wasn', "wasn't", 'weren', "weren't", 'won', "won't", 'wouldn', "wouldn't"]

# %%
stop_words = set(stopwords.words('english'))

# %%
def remove_stopwords(document):
    "Return the articles after remvoing stopwords"
    article_tokens = word_tokenize(document) 
    filtered_article = [word for word in article_tokens if not word in stop_words] 
    return " ".join(filtered_article)

# %%
#removing stopwords
df_all_comments.V_COMMENTS_2=df_all_comments.V_COMMENTS_2.apply(lambda x: remove_stopwords(x))

# %% [markdown]
# ### step-4 removing Punctuations

# %%
print(f"These are the punctuations which string.punctuation consist :  {string.punctuation}")
# Out:
# These are the punctuations which string.punctuation consist :  !"#$%&'()*+,-./:;<=>?@[\]^_`{|}~

# %%
'[%s]' % re.escape(string.punctuation)
# Out:
# '[!"\\#\\$%\\&\'\\(\\)\\*\\+,\\-\\./:;<=>\\?@\\[\\\\\\]\\^_`\\{\\|\\}\\~]'

# %%
#removing Punctuations 
df_all_comments.V_COMMENTS_2=df_all_comments.V_COMMENTS_2.apply(lambda x: re.sub('[%s]' % re.escape(string.punctuation), '', x))

# %%
df_all_comments.V_COMMENTS_2
# Out:
# 0                                                                                                                                                                                                                                                                                            mismatch id number nric
# 1                                                                                                                                                                                                                                                                                            mismatch id number nric
# 2                                                                                                                                                                                                                                                                                            mismatch year birth yob
# 3                                                                                                                                                                                                                                                                                            mismatch id number nric
# 4                                                                                                                                                                                                                                                                                   mismatch full name sound similar
#                                                                                                                                                              ...
# 221574                                    mismatch name nric date birth profile customer name nric date birth profile shop sales assistants monaliza mastura sb computer st per host watch person per host based customer number name nric date birth profile pep related pep spouse  mahani dhter  dhter  son  son
# 221575                                                           mismatch name nric date birth profile customer per host name nric date birth profile housewifehousehusband per host watch person per host based customer number name nric date birth profile pep related pep spouse  mahani dhter  dhter  son  son
# 221576                                                                                                                                                                                                           mismatch id number nric  watch person bank customer nric gcif  pep transaction apex  customers nric
# 221577                                                                                                                                                                                                           mismatch id number nric  watch person bank customer nric gcif  pep transaction apex  customers nric
# 221578    mismatch profile adverse news reported detained punjab police patiala alleged involvement planning terror acts target killings  case registered unlawful activities prevention act  information reported apex account customer shows active transaction since  hence highly unlikely watchperson customer
# Name: V_COMMENTS_2, Length: 221574, dtype: object

# %%
# #removing digits
# df_all_comments.V_COMMENTS_2 = df_all_comments.V_COMMENTS_2.apply(lambda x: re.sub('\d*','', x))

# df_all_comments.V_COMMENTS_2[50]

# %% [markdown]
# There are still some marks like quotation marks, hypen and apostrophe still remaining in the article, we also need to remove them.

# %%
# df_all_comments.V_COMMENTS_2 = df_all_comments.V_COMMENTS_2.apply(remove_extra_marks)

# %%
# def remove_extra_marks(article):
#     extra_keys = ["’","—","”","“"]
#     article_tokens = word_tokenize(article) 
#     filtered_article = [word for word in article_tokens if not word in extra_keys] 
#     return " ".join(filtered_article)
    
# df_all_comments.V_COMMENTS_2 = df_all_comments.V_COMMENTS_2.apply(remove_extra_marks)

# %%
#printing arbitrary example to visulise clean data
df_all_comments.V_COMMENTS_2[50]

# %% [markdown]
# ## bi-grams /tri-grams

# %%
import gensim
from gensim.utils import simple_preprocess

def sent_to_words(sentences):
    for sentence in sentences:
        yield(gensim.utils.simple_preprocess(str(sentence), deacc=True))  # deacc=True removes punctuations

data = df_all_comments.V_COMMENTS_2.values.tolist()
data_words = list(sent_to_words(data))
print(data_words)



# Build the bigram and trigram models
bigram = gensim.models.Phrases(data_words, min_count=5, threshold=100) # higher threshold fewer phrases.
trigram = gensim.models.Phrases(bigram[data_words], threshold=100)
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
bigram

# %%
# Faster way to get a sentence clubbed as a trigram/bigram
bigram_mod = gensim.models.phrases.Phraser(bigram)
trigram_mod = gensim.models.phrases.Phraser(trigram)
# bigram_mod

# %%
# Form Bigrams
# dfmake_bigrams(data_words_nostops)

texts=df_all_comments.V_COMMENTS_2.apply(lambda x: x.split()).to_list()

# %%
def make_bigrams(texts):
    return [bigram_mod[doc] for doc in texts]

def make_trigrams(texts):
    return [trigram_mod[bigram_mod[doc]] for doc in texts]
def lemmatization(texts):
    """https://spacy.io/api/annotation"""
    texts_out = []
    for sent in texts:
        doc = nlp(" ".join(sent)) 
        texts_out.append([token.lemma_ for token in doc])
    return texts_out

# %%
data_words_bigrams=make_bigrams(data_words)

# %%
data_words_trigrams=make_trigrams(data_words_bigrams)

# %%
data_words_bigrams
data_words_trigrams
# Out:
# [['mismatch', 'id', 'number', 'nric'],
#  ['mismatch', 'id', 'number', 'nric'],
#  ['mismatch', 'year', 'birth', 'yob'],
#  ['mismatch', 'id', 'number', 'nric'],
#  ['mismatch', 'full', 'name', 'sound', 'similar'],
#  ['mismatch', 'full', 'name', 'sound', 'similar'],
#  ['mismatch', 'full', 'name', 'sound', 'similar'],
#  ['mismatch', 'id', 'number', 'nric'],
#  ['mismatch', 'date', 'birth', 'dob'],
#  ['mismatch', 'full', 'name', 'sound', 'similar'],
#  ['mismatch', 'full', 'name', 'sound', 'similar'],
#  ['match', 'id', 'number', 'nric'],
#  ['mismatched', 'nric'],
#  ['match', 'id', 'number', 'nric'],
#  ['mismatch', 'date', 'birth', 'dob'],
#  ['mismatch',
#   'yobage',
#   'comparison',
#   'made',
#   'customers',
#   'yob',
#   'bank',
#   'kyc',
#   'uco',
#   'watchpersons',
#   'yob',
#   'refinitive'],
#  ['mismatch', 'identification', 'number', 'nric'],
#  ['mismatch', 'id', 'number', 'nric'],
#  ['mismatch', 'id', 'number', 'nric'],
#  ['mismatch', 'full', 'name', 'name', 'sounds', 'similar'],
#  ['mismatch', 'full', 'name', 'sound', 'similar'],
#  ['mismatch', 'id', 'number', 'nric'],
#  ['mismatch', 'full', 'name', 'sound', 'similar'],
#  ['match', 'name', 'nric', 'dob', 'nationality'],
#  ['mismatch', 'id', 'number', 'nric'],
#  ['mismatch', 'id', 'number', 'nric', 'date', 'birth'],
#  ['mismatch', 'id', 'number', 'nric'],
#  ['mismatch', 'id', 'number', 'nric'],
#  ['mismatch',
#   'yobage',
#   'comparison',
#   'made',
#   'customers',
#   'yob',
#   'bank',
#   'kyc',
#   'uco',
#   'watchpersons',
#   'yob',
#   'refinitive'],
#  ['mismatch', 'id', 'number', 'nric'],
#  ['mismatch', 'id', 'number', 'nric'],
#  ['mismatch',
#   'full',
#   'name',
#   'sound',
#   'similar',
#   'though',
#   'name',
#   'close',
#   'match',
#   'ie',
#   'onetwo',
#   'different',
#   'characters',
#   'sound',
#   'similar',
#   'highly',
#   'unlikely',
#   'person'],
#  ['mismatch', 'id', 'number', 'nric', 'dob'],
#  ['mismatch', 'full', 'name', 'name', 'sound', 'similar'],
#  ['mismatch', 'nric', 'dob'],
#  ['mismatch', 'id', 'number', 'nric'],
#  ['mismatch', 'year', 'birth', 'yob'],
#  ['mismatch', 'id', 'number', 'nric'],
#  ['mismatch',
#   'full',
#   'name',
#   'native',
#   'name',
#   'character',
#   'difference',
#   'comparison',
#   'made',
#   'customers',
#   'official',
#   'document',
#   'passport',
#   'copy',
#   'edms',
#   'watchpersons',
#   'name',
#   'refinitive'],
#  ['mismatch', 'full', 'name', 'sound', 'similar'],
#  [],
#  ['mismatch', 'id', 'number', 'nric', 'date', 'birth', 'dob'],
#  ['mismatch', 'id', 'number', 'nric', 'dob'],
#  ['mismatch', 'full', 'name'],
#  ['mismatch', 'id', 'number', 'nric', 'dob'],
#  ['mismatch', 'id', 'number', 'nric', 'date', 'birth', 'dob'],
#  ['mismatch', 'year', 'birth', 'yob'],
#  ['match', 'name', 'gender', 'id', 'number', 'nric', 'nationality'],
#  ['mismatch',
#   'full',
#   'name',
#   'name',
#   'sound',
#   'similar',
#   'though',
#   'name',
#   'close',
#   'match',
#   'eg',
#   'one',
#   'two',
#   'different',
#   'characters',
#   'sound',
#   'similar',
#   'highly',
#   'unlikely',
#   'person'],
#  ['mismatch', 'id', 'number', 'nric', 'dob'],
#  ['mismatched', 'full', 'name', 'sound', 'similar'],
#  ['mismatch', 'full', 'name', 'sound', 'similar'],
#  ['match', 'nric'],
#  ['match', 'name', 'gender', 'dob', 'nationality', 'id', 'number', 'nric'],
#  ['match', 'name', 'gender', 'nric', 'nationality'],
#  ['mismatch',
#   'full',
#   'name',
#   'native',
#   'name',
#   'character',
#   'difference',
#   'comparison',
#   'made',
#   'customers',
#   'official',
#   'document',
#   'passport',
#   'copy',
#   'uco',
#   'watchpersons',
#   'name',
#   'refinitive'],
#  ['mismatch',
#   'id',
#   'number',
#   'nric',
#   'dob',
#   'full',
#   'name',
#   'sound',
#   'similar'],
#  ['match', 'name', 'nric'],
#  ['mismatch', 'full', 'name', 'name', 'sound', 'similar'],
#  ['mismatch', 'dob'],
#  ['mismatch', 'id', 'number', 'nric'],
#  ['mismatch',
#   'full',
#   'name',
#   'native',
#   'name',
#   'character',
#   'difference',
#   'comparison',
#   'made',
#   'customers',
#   'official',
#   'document',
#   'passport',
#   'copy',
#   'edms',
#   'watchpersons',
#   'name',
#   'refinitive'],
#  ['match', 'name', 'id', 'number', 'nric'],
#  ['match',
#   'name',
#   'dob',
#   'nationality',
#   'id',
#   'number',
#   'nric',
#   'id',
#   'number',
#   'passport',
#   'number'],
#  ['mismatch', 'full', 'name', 'sound', 'similar'],
#  ['match', 'name', 'gender', 'dob', 'nric', 'nationality'],
#  ['match', 'full', 'name', 'id', 'number', 'nric'],
#  ['match',
#   'name',
#   'gender',
#   'id',
#   'number',
#   'nric',
#   'date',
#   'birth',
#   'nationality'],
#  ['match', 'date', 'birth', 'dob'],
#  ['mismatch', 'id', 'number', 'nric'],
#  ['match', 'identification', 'number', 'nric'],
#  ['mismatch', 'full', 'name', 'name', 'sounds', 'similar'],
#  ['mismatch', 'nric'],
#  ['mismatch', 'id', 'number', 'nric', 'date', 'birth'],
#  [],
#  ['mismatch', 'date', 'birth'],
#  ['mismatch', 'id', 'number', 'nric', 'date', 'birth', 'dob'],
#  ['mismatch', 'date', 'birth', 'dob'],
#  ['mismatch',
#   'full',
#   'name',
#   'native',
#   'name',
#   'character',
#   'difference',
#   'world',
#   'check',
#   'passport',
#   'image',
#   'per',
#   'edms'],
#  ['mismatched', 'date', 'birth'],
#  ['match', 'id', 'number', 'nric'],
#  ['mismatch', 'year', 'birth', 'yob'],
#  ['match', 'id', 'number', 'nric'],
#  ['mismatch', 'full', 'name', 'sound', 'similar'],
#  ['matched', 'name', 'nric', 'dob'],
#  ['match', 'id', 'full', 'name'],
#  ['mismatch', 'full', 'name', 'sound', 'similar'],
#  ['match', 'full', 'name', 'id', 'number', 'nric', 'gender', 'nationality'],
#  ['mismatch', 'year', 'birth', 'yob'],
#  ['mismatch',
#   'full',
#   'namedate',
#   'birth',
#   'dobnric',
#   'number',
#   'customer',
#   'watchperson',
#   'name',
#   'sound',
#   'similar',
#   'different',
#   'nric',
#   'number',
#   'dob'],
#  ['mismatch',
#   'full',
#   'name',
#   'native',
#   'name',
#   'character',
#   'difference',
#   'comparison',
#   'made',
#   'customers',
#   'name',
#   'bank',
#   'kyc',
#   'uco',
#   'watchpersons',
#   'name',
#   'refinitive'],
#  ['mismatch', 'id', 'number', 'nric'],
#  ['match',
#   'name',
#   'dob',
#   'nationality',
#   'id',
#   'number',
#   'nric',
#   'id',
#   'number',
#   'passport',
#   'number'],
#  ['mismatch',
#   'full',
#   'name',
#   'mismatch',
#   'watchpersons',
#   'name',
#   'native',
#   'language',
#   'customers',
#   'name',
#   'native',
#   'language',
#   'different'],
#  ['mismatch', 'full', 'name', 'name', 'sound', 'similar'],
#  ['mismatch', 'full', 'name', 'structure'],
#  ['mismatch', 'yob'],
#  ['mismatch', 'full', 'name'],
#  ['match',
#   'name',
#   'gender',
#   'date',
#   'birth',
#   'dob',
#   'nationality',
#   'id',
#   'number',
#   'nric'],
#  ['mismatch',
#   'date',
#   'birth',
#   'dobnric',
#   'number',
#   'customer',
#   'watchperson',
#   'different',
#   'nric',
#   'number',
#   'dob'],
#  ['mismatch',
#   'full',
#   'name',
#   'native',
#   'name',
#   'character',
#   'difference',
#   'comparison',
#   'made',
#   'customers',
#   'official',
#   'document',
#   'passport',
#   'uco',
#   'watchpersons',
#   'name',
#   'refinitive'],
#  ['mismatch', 'full', 'name', 'native', 'name', 'character', 'difference'],
#  ['mismatch', 'full', 'name', 'sound', 'similar'],
#  ['match',
#   'name',
#   'gender',
#   'id',
#   'number',
#   'nric',
#   'date',
#   'birth',
#   'dob',
#   'nationality'],
#  ['mismatch', 'full', 'name', 'structure'],
#  ['match', 'id', 'number', 'nric'],
#  ['alert', 'closed', 'hit_fico_previously'],
#  ['mismatch', 'full', 'name', 'sound', 'similar'],
#  ['mismatch', 'full', 'name', 'name', 'sound', 'similar'],
#  ['mismatch', 'full', 'name', 'structure'],
#  ['mismatch',
#   'year',
#   'birth',
#   'yobage',
#   'comparison',
#   'made',
#   'customers',
#   'yob',
#   'bank',
#   'kyc',
#   'uco',
#   'watchpersons',
#   'yob',
#   'refinitive'],
#  ['mismatch', 'id', 'number', 'nric', 'dob'],
#  ['match', 'name', 'id', 'number', 'dob', 'nationality'],
#  ['mismatch', 'date', 'birth', 'dob'],
#  ['mismatch', 'id', 'number', 'nric'],
#  ['match', 'nric'],
#  ['mismatch',
#   'full',
#   'name',
#   'native',
#   'name',
#   'character',
#   'difference',
#   'comparison',
#   'made',
#   'customers',
#   'name',
#   'native',
#   'character',
#   'chinese',
#   'native',
#   'character',
#   'world',
#   'check'],
#  ['mismatch', 'id', 'number', 'nric'],
#  ['match', 'full', 'name', 'id', 'number', 'nric', 'date', 'birth', 'dob'],
#  ['mismatch', 'id', 'number', 'nric'],
#  ['mismatch', 'full', 'name', 'structure'],
#  ['match', 'id', 'number', 'nric', 'date', 'birth', 'dob', 'gender'],
#  ['mismatch', 'date', 'birth', 'dob'],
#  ['mismatch',
#   'full',
#   'name',
#   'sound',
#   'similar',
#   'hence',
#   'highly',
#   'unlikely',
#   'person'],
#  ['match', 'id', 'full', 'name'],
#  ['mismatch', 'full', 'name', 'name', 'sound', 'similar'],
#  ['mismatch', 'full', 'name', 'name', 'sounds', 'similar'],
#  ['mismatch', 'id', 'number', 'nric'],
#  ['mismatch', 'full', 'name', 'sound', 'similar'],
#  ['match', 'name', 'gender', 'dob', 'nationality', 'id', 'number', 'nric'],
#  ['mismatch',
#   'id',
#   'number',
#   'nric',
#   'dob',
#   'full',
#   'name',
#   'sound',
#   'similar'],
#  ['match', 'id', 'number', 'nric'],
#  ['mismatch', 'full', 'name', 'sound', 'similar'],
#  ['mismatch', 'date', 'birth', 'dob'],
#  ['mismatch', 'year', 'birth', 'yob'],
#  ['mismatch', 'full', 'name', 'structure'],
#  ['match', 'name', 'dob', 'id', 'number', 'nric'],
#  ['mismatched', 'yob', 'watch', 'person', 'yob', 'info', 'refinitiv'],
#  ['mismatch', 'id', 'number', 'nric'],
#  ['mismatch',
#   'yobage',
#   'comparison',
#   'made',
#   'customers',
#   'yob',
#   'bank',
#   'kyc',
#   'uco',
#   'watchpersons',
#   'yob',
#   'refinitive'],
#  ['match', 'full', 'name', 'id', 'number', 'nric'],
#  ['mismatch', 'id', 'number', 'nric'],
#  ['mismatch', 'year', 'birth', 'yob'],
#  ['mismatch',
#   'full',
#   'name',
#   'native',
#   'name',
#   'character',
#   'difference',
#   'refer',
#   'customers',
#   'passport',
#   'details',
#   'dms',
#   'uco',
#   'watchperson',
#   'refer',
#   'refinitiv'],
#  ['mismatch', 'id', 'number', 'nric'],
#  ['match', 'name', 'id', 'number', 'nric', 'date', 'birth', 'dob'],
#  ['mismatch',
#   'customer',
#   'worked',
#   'manufacturing',
#   'labourers',
#   'hence',
#   'reflected',
#   'pep'],
#  ['matched', 'nric'],
#  ['mismatch', 'id', 'number', 'nric'],
#  ['mismatch', 'date', 'birth', 'dob'],
#  ['mismatch',
#   'id',
#   'number',
#   'nric',
#   'dob',
#   'full',
#   'name',
#   'sound',
#   'similar'],
#  ['mismatch', 'year', 'worldcheck', 'watchlist', 'yob'],
#  ['mismatch',
#   'year',
#   'birth',
#   'comparison',
#   'made',
#   'customers',
#   'yob',
#   'bank',
#   'kyc',
#   'uco',
#   'watchpersons',
#   'yob',
#   'refinitive'],
#  ['mismatch',
#   'full',
#   'name',
#   'native',
#   'name',
#   'character',
#   'difference',
#   'comparison',
#   'made',
#   'customers',
#   'name',
#   'bank',
#   'kyc',
#   'uco',
#   'watchpersons',
#   'name',
#   'refinitive'],
#  ['mismatch',
#   'full',
#   'name',
#   'native',
#   'name',
#   'character',
#   'difference',
#   'comparison',
#   'made',
#   'customers',
#   'official',
#   'document',
#   'passport',
#   'copy',
#   'uco',
#   'watchpersons',
#   'name',
#   'refinitiv'],
#  ['mismatch', 'id', 'number', 'nric'],
#  ['mismatch', 'full', 'name', 'name', 'sound', 'similar'],
#  ['customer',
#   'common',
#   'name',
#   'native',
#   'country',
#   'lack_unique_identifiers_hits',
#   'generated_us_meaningfully',
#   'review',
#   'hits',
#   'also',
#   'indicator',
#   'suggest',
#   'customer',
#   'person',
#   'potential_matches_risk',
#   'based',
#   'approach',
#   'customer',
#   'tagged',
#   'high_risk_solely',
#   'based',
#   'potential',
#   'name',
#   'match'],
#  ['mismatch',
#   'yobage',
#   'comparison',
#   'made',
#   'customers',
#   'yob',
#   'bank',
#   'kyc',
#   'uco',
#   'watchpersons',
#   'yob',
#   'refinitiv'],
#  ['match',
#   'name',
#   'gender',
#   'id',
#   'number',
#   'date',
#   'birth',
#   'dob',
#   'nationality'],
#  ['mismatch', 'id', 'number', 'nric'],
#  ['match', 'date', 'birth'],
#  ['match',
#   'full',
#   'name',
#   'nric',
#   'number',
#   'date',
#   'birth',
#   'year',
#   'birth',
#   'gender',
#   'nationality'],
#  ['match',
#   'name',
#   'gender',
#   'id',
#   'number',
#   'nric',
#   'date',
#   'birth',
#   'dob',
#   'nationality'],
#  ['mismatch', 'date', 'birth'],
#  ['mismatch', 'full', 'name', 'structure'],
#  ['mismatch', 'id', 'number', 'nric', 'date', 'birth', 'dob'],
#  ['mismatch',
#   'full',
#   'name',
#   'sound',
#   'similar',
#   'though',
#   'name',
#   'close',
#   'match',
#   'ie',
#   'onetwo',
#   'different',
#   'characters',
#   'sound',
#   'similar',
#   'highly',
#   'unlikely',
#   'person'],
#  ['mismatch',
#   'full',
#   'name',
#   'native',
#   'name',
#   'character',
#   'difference',
#   'per',
#   'customer',
#   'passport',
#   'edms'],
#  ['match',
#   'date',
#   'birth',
#   'dob',
#   'match',
#   'id',
#   'number',
#   'passport',
#   'number'],
#  ['mismatch', 'year', 'birth', 'yob'],
#  ['identifier',
#   'information',
#   'available',
#   'watch',
#   'list',
#   'assess',
#   'conclude'],
#  ['mismatch', 'year', 'birth', 'yob', 'refer', 'world', 'check'],
#  ['match', 'name', 'gender', 'dob', 'nric', 'nationality'],
#  ['mismatch', 'id', 'number', 'nric'],
#  ['match', 'full', 'name', 'date', 'birth', 'dob', 'id', 'number'],
#  ['mismatch', 'id', 'number', 'nric'],
#  [],
#  ['mismatch',
#   'year',
#   'birth',
#   'yobage',
#   'comparison',
#   'made',
#   'customers',
#   'dob',
#   'bank',
#   'kyc',
#   'uco',
#   'watchpersons',
#   'dob',
#   'refinitive'],
#  ['mismatch', 'date', 'birth', 'dob'],
#  ['match', 'full', 'name', 'gender', 'nric', 'nationality'],
#  ['match', 'full', 'name', 'id', 'number', 'nric', 'date', 'birth', 'dob'],
#  ['mismatch',
#   'full',
#   'name',
#   'sound',
#   'similar',
#   'though',
#   'name',
#   'close',
#   'match',
#   'ie',
#   'onetwo',
#   'different',
#   'characters',
#   'sound',
#   'similar',
#   'highly',
#   'unlikely',
#   'person'],
#  ['mismatch', 'full', 'name', 'sound', 'similar'],
#  ['match',
#   'full',
#   'name',
#   'date',
#   'birth',
#   'dob',
#   'id',
#   'number',
#   'passport',
#   'number'],
#  ['mismatch', 'full', 'name', 'sound', 'similar'],
#  ['mismatch',
#   'full',
#   'name',
#   'native',
#   'name',
#   'character',
#   'difference',
#   'comparison',
#   'made',
#   'customers',
#   'official',
#   'document',
#   'passport',
#   'uco',
#   'watchpersons',
#   'name',
#   'refinitive'],
#  ['match', 'date', 'birth', 'dob'],
#  ['mismatch', 'year', 'birth', 'yob'],
#  ['mismatch', 'obvious', 'name', 'native', 'name', 'character', 'difference'],
#  ['mismatch',
#   'full',
#   'name',
#   'sound',
#   'similar',
#   'edms',
#   'search',
#   'third',
#   'party',
#   'bond_documents'],
#  ['match',
#   'name',
#   'gender',
#   'nationality',
#   'date',
#   'birth',
#   'dob',
#   'id',
#   'number',
#   'nric'],
#  ['mismatched',
#   'profile',
#   'customer',
#   'manufacturing',
#   'labourer',
#   'watch',
#   'person',
#   'pep'],
#  ['mismatch',
#   'year',
#   'birth',
#   'yob',
#   'watchperson',
#   'yob',
#   'per',
#   'worldcheck',
#   'inferred',
#   'inferred'],
#  ['mismatch', 'id', 'number', 'nric'],
#  ['mismatch',
#   'full',
#   'name',
#   'sound',
#   'similar',
#   'per',
#   'amla',
#   'full',
#   'name',
#   'ruled',
#   'name',
#   'mismatch',
#   'though',
#   'name',
#   'close',
#   'match',
#   'eg',
#   'onetwo',
#   'different',
#   'characters',
#   'sound',
#   'similar',
#   'highly',
#   'unlikely',
#   'person'],
#  ['mismatch',
#   'full',
#   'name',
#   'sound',
#   'similar',
#   'per',
#   'amla',
#   'full',
#   'name',
#   'ruled',
#   'name',
#   'mismatch',
#   'though',
#   'name',
#   'close',
#   'match',
#   'eg',
#   'onetwo',
#   'different',
#   'characters',
#   'sound',
#   'similar',
#   'highly',
#   'unlikely',
#   'person'],
#  ['mismatch', 'year', 'birth', 'yob'],
#  ['match', 'id', 'number', 'identification'],
#  ['match', 'id', 'number', 'nric'],
#  ['mismatch', 'full', 'name'],
#  ['mismatch',
#   'customer',
#   'worked',
#   'mining',
#   'construction',
#   'labourers',
#   'hence',
#   'reflected',
#   'pep'],
#  ['mismatch', 'id', 'number', 'nric'],
#  ['mismatch', 'id', 'number', 'nric', 'date', 'birth', 'mhi', 'csc', 'mr'],
#  ['mismatch', 'date', 'birth'],
#  ['mismatch', 'id', 'number', 'nric'],
#  ['mismatch', 'full', 'name', 'sound', 'similar'],
#  ['mismatch',
#   'year',
#   'birthage',
#   'comparison',
#   'made',
#   'customers',
#   'yob',
#   'bank',
#   'kyc',
#   'uco',
#   'watchpersons',
#   'yob',
#   'refinitive'],
#  ['mismatch',
#   'full',
#   'name',
#   'native',
#   'name',
#   'character',
#   'difference',
#   'comparison',
#   'made',
#   'customers',
#   'official',
#   'document',
#   'passport',
#   'copy',
#   'edms',
#   'watchpersons',
#   'native',
#   'character',
#   'name'],
#  ['mismatch', 'full', 'name', 'sound', 'similar'],
#  ['mismatched', 'dob'],
#  ['mismatch',
#   'full',
#   'name',
#   'sound',
#   'similar',
#   'refer',
#   'bank',
#   'group',
#   'anti_money_laundering',
#   'countering_financing',
#   'terrorism',
#   'procedures_sub_section_ai',
#   'pg',
#   'ruled',
#   'name',
#   'mismatch',
#   'though',
#   'name',
#   'close',
#   'eg',
#   'onetwo',
#   'different',
#   'characters',
#   'sound',
#   'similar',
#   'highly',
#   'unlikely',
#   'person'],
#  ['match', 'name', 'gender', 'dob', 'nationality', 'id', 'number'],
#  ['mismatch',
#   'id',
#   'number',
#   'nric',
#   'watch',
#   'person',
#   'datuk',
#   'azhar',
#   'ahmad',
#   'mbb',
#   'customer',
#   'nric',
#   'gcif',
#   'related',
#   'ucif',
#   'profile',
#   'senior',
#   'government',
#   'officials_kementerian_perumahan',
#   'dan',
#   'kerajaan_tempatan',
#   'per',
#   'apex',
#   'saving',
#   'account',
#   'watchperson',
#   'transaction',
#   'son',
#   'muhammad',
#   'faizal_azhar',
#   'nric',
#   'gcif',
#   'related',
#   'ucif',
#   'son',
#   'also',
#   'transaction',
#   'watchperson',
#   'spouse',
#   'nuraini_mohammed_hanafiah',
#   'also',
#   'mbb',
#   'customer',
#   'nric',
#   'gcif',
#   'related',
#   'ucif',
#   'customers',
#   'nric',
#   'different',
#   'hence',
#   'person'],
#  ['mismatch', 'year', 'birth', 'yob', 'refer', 'worldcheck'],
#  ['match', 'full', 'name', 'id', 'number', 'nric', 'date', 'birth', 'dob'],
#  ['mismatch', 'id', 'number', 'nric'],
#  ['mismatch', 'id', 'number', 'nric', 'mia', 'csc', 'mr'],
#  ['mismatch',
#   'id',
#   'number',
#   'nric',
#   'watch',
#   'person',
#   'datuk',
#   'azhar',
#   'ahmad',
#   'mbb',
#   'customer',
#   'nric',
#   'gcif',
#   'related',
#   'ucif',
#   'profile',
#   'senior',
#   'government',
#   'officials_kementerian_perumahan',
#   'dan',
#   'kerajaan_tempatan',
#   'per',
#   'apex',
#   'saving',
#   'account',
#   'watchperson',
#   'transaction',
#   'son',
#   'muhammad',
#   'faizal_azhar',
#   'nric',
#   'gcif',
#   'related',
#   'ucif',
#   'son',
#   'also',
#   'transaction',
#   'watchperson',
#   'spouse',
#   'nuraini_mohammed_hanafiah',
#   'also',
#   'mbb',
#   'customer',
#   'nric',
#   'gcif',
#   'related',
#   'ucif',
#   'customers',
#   'nric',
#   'different',
#   'hence',
#   'person',
#   'mod'],
#  ['mismatch', 'id', 'number', 'nric', 'mna', 'csc', 'mr'],
#  ['mismatch', 'full', 'name', 'structure'],
#  ['mismatch',
#   'yobage',
#   'comparison',
#   'made',
#   'customers',
#   'yob',
#   'bank',
#   'kyc',
#   'uco',
#   'watchpersons',
#   'yob',
#   'refinitive'],
#  ['mismatch', 'nric'],
#  ['match', 'name', 'nric'],
#  ['match',
#   'full',
#   'namedate',
#   'birth',
#   'dobnric',
#   'number',
#   'customer',
#   'watchperson',
#   'name',
#   'nric',
#   'number',
#   'dob'],
#  ['mismatch', 'id', 'number', 'nric', 'mfk', 'csc', 'mr'],
#  ['mismatch', 'id', 'number', 'nric'],
#  ['match', 'id', 'number', 'nric', 'match', 'name'],
#  ['mismatch', 'full', 'name', 'sound', 'similar'],
#  ['mismatch',
#   'id',
#   'number',
#   'nric',
#   'watch',
#   'person',
#   'datuk',
#   'azhar',
#   'ahmad',
#   'mbb',
#   'customer',
#   'nric',
#   'gcif',
#   'related',
#   'ucif',
#   'profile',
#   'senior',
#   'government',
#   'officials_kementerian_perumahan',
#   'dan',
#   'kerajaan_tempatan',
#   'per',
#   'apex',
#   'saving',
#   'account',
#   'watchperson',
#   'transaction',
#   'son',
#   'muhammad',
#   'faizal_azhar',
#   'nric',
#   'gcif',
#   'related',
#   'ucif',
#   'son',
#   'also',
#   'transaction',
#   'watchperson',
#   'spouse',
#   'nuraini_mohammed_hanafiah',
#   'also',
#   'mbb',
#   'customer',
#   'nric',
#   'gcif',
#   'related',
#   'ucif',
#   'customers',
#   'nric',
#   'different',
#   'hence',
#   'person'],
#  ['match', 'id', 'number', 'nric'],
#  ['mismatch', 'id', 'number', 'nric'],
#  ['match', 'name', 'gender', 'id', 'number', 'nric', 'date', 'birth'],
#  ['mismatch', 'full', 'name', 'structure'],
#  ['mismatch', 'year', 'birth', 'yob'],
#  ['match', 'name', 'gender', 'date', 'birth', 'dob', 'nationality'],
#  ['match', 'full', 'name', 'nric', 'number', 'date', 'birth', 'year', 'birth'],
#  ['match', 'name', 'gender', 'dob', 'nationality', 'id', 'number', 'nric'],
#  ['match', 'id', 'number', 'nric'],
#  ['mismatch',
#   'id',
#   'number',
#   'nric',
#   'date',
#   'birth',
#   'watchperson',
#   'bank',
#   'customer',
#   'ucif'],
#  ['mismatch',
#   'full',
#   'name',
#   'native',
#   'name',
#   'character',
#   'difference',
#   'compare',
#   'passport',
#   'watchperson',
#   'aliases'],
#  ['mismatch', 'year', 'birth', 'yob'],
#  ['mismatch',
#   'year',
#   'birth',
#   'yob',
#   'watchperson',
#   'yob',
#   'per',
#   'world',
#   'check'],
#  ['match', 'full', 'name', 'id', 'number', 'nric', 'date', 'birth', 'dob'],
#  ['match', 'full', 'name', 'match', 'id', 'number', 'nric'],
#  ['mismatch', 'id', 'number', 'nric'],
#  ['match', 'id', 'number', 'nric'],
#  ['mismatch',
#   'full',
#   'name',
#   'native',
#   'name',
#   'character',
#   'difference',
#   'refer',
#   'customers',
#   'passport',
#   'details',
#   'dms',
#   'uco',
#   'watchperson',
#   'refer',
#   'refinitiv'],
#  ['mismatch',
#   'id',
#   'number',
#   'nric',
#   'watch',
#   'person',
#   'datuk',
#   'azhar',
#   'ahmad',
#   'mbb',
#   'customer',
#   'nric',
#   'gcif',
#   'related',
#   'ucif',
#   'profile',
#   'senior',
#   'government',
#   'officials_ahli_dewan',
#   'negara_parlimen',
#   'malaysia',
#   'customers',
#   'nric',
#   'different',
#   'hence',
#   'person'],
#  ['mismatch',
#   'full',
#   'name',
#   'native',
#   'name',
#   'chinese',
#   'character',
#   'difference',
#   'comparison',
#   'made',
#   'customers',
#   'official',
#   'document',
#   'passport',
#   'uco',
#   'watchperson',
#   'info',
#   'world',
#   'check',
#   'refer',
#   'world',
#   'check',
#   'uco'],
#  ['mismatch',
#   'full',
#   'name',
#   'native',
#   'name',
#   'character',
#   'difference',
#   'world',
#   'check',
#   'vs',
#   'passport',
#   'uco'],
#  ['mismatch', 'year', 'birth', 'yob', 'world', 'check'],
#  [],
#  ['mismatch', 'full', 'name', 'name', 'sound', 'similar'],
#  ['mismatched', 'yob', 'watch', 'person', 'yob', 'info', 'refinitiv'],
#  ['mismatch', 'id', 'number', 'nric'],
#  ['match', 'name', 'gender', 'dob', 'passport', 'nationality'],
#  ['alert', 'closed', 'hit_fico_previously'],
#  ['mismatch', 'full', 'name', 'sound', 'similar'],
#  ['mismatch', 'full', 'name', 'sound', 'similar'],
#  ['mismatch', 'id', 'number', 'nric'],
#  ['match',
#   'id',
#   'number',
#   'passport',
#   'number',
#   'match',
#   'date',
#   'birth',
#   'dob',
#   'match',
#   'full',
#   'name'],
#  ['mismatch',
#   'customer',
#   'worked',
#   'manufacturing',
#   'labourers',
#   'hence',
#   'reflected',
#   'pep'],
#  ['mismatch',
#   'full',
#   'name',
#   'name',
#   'sound',
#   'similar',
#   'though',
#   'name',
#   'close',
#   'match',
#   'eg',
#   'one',
#   'two',
#   'different',
#   'characters',
#   'sound',
#   'similar',
#   'highly',
#   'unlikely',
#   'person'],
#  ['mismatch', 'date', 'birth', 'dob'],
#  ['mismatch', 'full', 'name', 'sound', 'similar'],
#  ['mismatch',
#   'full',
#   'name',
#   'native',
#   'name',
#   'character',
#   'difference',
#   'refer',
#   'customers',
#   'passport',
#   'details',
#   'dms',
#   'uco',
#   'watchperson',
#   'refer',
#   'refinitiv'],
#  ['mismatch', 'id', 'number', 'nric', 'amc', 'csc', 'mr'],
#  ['mismatch',
#   'full',
#   'name',
#   'native',
#   'name',
#   'character',
#   'difference',
#   'edms',
#   'vs',
#   'world',
#   'check'],
#  ['mismatch',
#   'full',
#   'name',
#   'native',
#   'name',
#   'character',
#   'difference',
#   'comparison',
#   'made',
#   'customers',
#   'official',
#   'document',
#   'passport',
#   'copy',
#   'uco',
#   'dms',
#   'watchpersons',
#   'name',
#   'refinitive'],
#  ['customer',
#   'common',
#   'name',
#   'native',
#   'country',
#   'lack_unique_identifiers_hits',
#   'generated_us_meaningfully',
#   'review',
#   'hits',
#   'also',
#   'indicator',
#   'suggest',
#   'customer',
#   'person',
#   'potential_matches_risk',
#   'based',
#   'approach',
#   'customer',
#   'tagged',
#   'high_risk_solely',
#   'based',
#   'potential',
#   'name',
#   'match'],
#  ['match', 'name', 'id', 'number', 'nric'],
#  ['match', 'id', 'number', 'nric', 'date', 'birth', 'dob', 'gender'],
#  ['mismatch',
#   'fathers',
#   'name',
#   'difference',
#   'fathers',
#   'name',
#   'comparison',
#   'made',
#   'customers',
#   'official',
#   'document',
#   'watchperson',
#   'info'],
#  ['mismatch',
#   'full',
#   'name',
#   'native',
#   'name',
#   'character',
#   'difference',
#   'refer',
#   'uco',
#   'customer',
#   'native',
#   'character',
#   'name',
#   'available',
#   'customers',
#   'copy',
#   'passport',
#   'meanwhile',
#   'per',
#   'world',
#   'check',
#   'watchpersons',
#   'native',
#   'character',
#   'name',
#   'different',
#   'compared',
#   'customers',
#   'hence',
#   'highly',
#   'unlikely',
#   'customer',
#   'watchperson',
#   'person'],
#  ['mismatch',
#   'customer',
#   'worked',
#   'agricultural',
#   'forestry',
#   'farming',
#   'fishery',
#   'labourers',
#   'hence',
#   'reflected',
#   'pep'],
#  ['mismatch',
#   'full',
#   'name',
#   'native',
#   'name',
#   'character',
#   'difference',
#   'comparison',
#   'made',
#   'customers',
#   'name',
#   'bank',
#   'kyc',
#   'uco',
#   'watchpersons',
#   'name',
#   'refinitive'],
#  ['match', 'date', 'birth', 'dob', 'id', 'number'],
#  ['mismatch', 'id', 'number', 'nric'],
#  ['match', 'full', 'name', 'match', 'nric', 'match', 'date', 'birth', 'dob'],
#  ['match', 'id', 'number', 'nric', 'date', 'birth', 'dob', 'full', 'name'],
#  ['mismatch',
#   'yobage',
#   'comparison',
#   'made',
#   'customers',
#   'yob',
#   'bank',
#   'kyc',
#   'uco',
#   'watchpersons',
#   'yob',
#   'refinitive',
#   'watchpersons',
#   'yob'],
#  ['mismatch',
#   'full',
#   'name',
#   'name',
#   'sound',
#   'similar',
#   'though',
#   'name',
#   'close',
#   'match',
#   'eg',
#   'one',
#   'two',
#   'different',
#   'characters',
#   'sound',
#   'similar',
#   'highly',
#   'unlikely',
#   'person'],
#  ['mismatched', 'yob', 'watch', 'person', 'yob', 'info', 'refinitiv'],
#  ['mismatch',
#   'full',
#   'name',
#   'mismatch',
#   'watchpersons',
#   'name',
#   'native',
#   'language',
#   'customers',
#   'name',
#   'native',
#   'language',
#   'different'],
#  ['mismatch',
#   'full',
#   'name',
#   'sound',
#   'similar',
#   'per',
#   'amla',
#   'full',
#   'name',
#   'ruled',
#   'name',
#   'mismatch',
#   'though',
#   'name',
#   'close',
#   'match',
#   'eg',
#   'onetwo',
#   'different',
#   'characters',
#   'sound',
#   'similar',
#   'highly',
#   'unlikely',
#   'person',
#   'additional'],
#  ['mismatch', 'date', 'birth'],
#  ['mismatch',
#   'full',
#   'name',
#   'native',
#   'name',
#   'character',
#   'difference',
#   'native',
#   'character',
#   'different',
#   'review',
#   'dms',
#   'passport',
#   'copy',
#   'watch',
#   'person',
#   'native',
#   'character',
#   'per',
#   'world',
#   'check'],
#  ['match',
#   'full',
#   'name',
#   'nric',
#   'number',
#   'date',
#   'birth',
#   'year',
#   'birth',
#   'gender',
#   'nationality'],
#  ['mismatch',
#   'id',
#   'number',
#   'nric',
#   'watchperson',
#   'banks',
#   'customer',
#   'also_lares',
#   'uco',
#   'laration_cdd',
#   'member',
#   'senate',
#   'member_parti_pribumi',
#   'bersatu',
#   'malaysia',
#   'chief_united_malays',
#   'national_organisation_umno',
#   'kampung',
#   'sungai',
#   'daun',
#   'tengah',
#   'branch',
#   'reported',
#   'former',
#   'head',
#   'umno',
#   'jerai',
#   'reported',
#   'watchpersons',
#   'profile',
#   'refinitiv',
#   'watchpersons',
#   'nric',
#   'gcif',
#   'thus',
#   'customer',
#   'watchperson',
#   'person'],
#  ['mismatch',
#   'yobage',
#   'comparison',
#   'made',
#   'customers',
#   'yob',
#   'bank',
#   'kyc',
#   'uco',
#   'watchpersons',
#   'yob',
#   'refinitive',
#   'watchpersons',
#   'yob'],
#  ['match', 'name', 'gender', 'id', 'number', 'nric', 'date', 'birth', 'dob'],
#  [],
#  ['mismatch', 'full', 'name', 'name', 'sounds', 'similar'],
#  ['mismatch',
#   'year',
#   'birth',
#   'yob',
#   'watchlist',
#   'yob',
#   'refer',
#   'world',
#   'check'],
#  ['mismatch', 'full', 'name', 'word_count'],
#  ['mismatch',
#   'full',
#   'name',
#   'chinese',
#   'native',
#   'character',
#   'differ',
#   'based',
#   'world',
#   'check',
#   'aliases',
#   'vs',
#   'passport',
#   'copy',
#   'customer',
#   'uploaded',
#   'uco'],
#  ['match',
#   'full',
#   'name',
#   'gender',
#   'nationality',
#   'date',
#   'birth',
#   'dob',
#   'id',
#   'number',
#   'nric'],
#  ['mismatch', 'id', 'number', 'nric'],
#  ['match',
#   'full',
#   'name',
#   'match',
#   'date',
#   'birth',
#   'dob',
#   'match',
#   'id',
#   'number',
#   'nric'],
#  ['match',
#   'full',
#   'name',
#   'match',
#   'gender',
#   'match',
#   'date',
#   'birth',
#   'dob',
#   'match',
#   'id',
#   'number',
#   'nric'],
#  ['mismatch',
#   'full',
#   'name',
#   'sound',
#   'similar',
#   'edms',
#   'search',
#   'third',
#   'party',
#   'bond_documents'],
#  ['mismatch',
#   'year',
#   'birth',
#   'yob',
#   'based',
#   'refinitiv',
#   'watch',
#   'persons',
#   'year',
#   'birth'],
#  ['mismatch', 'nric'],
#  ['mismatch', 'id', 'number', 'nric', 'wfs', 'csc', 'mr'],
#  ['mismatch',
#   'full',
#   'name',
#   'name',
#   'sound',
#   'similar',
#   'though',
#   'name',
#   'close',
#   'match',
#   'eg',
#   'one',
#   'two',
#   'different',
#   'characters',
#   'sound',
#   'similar',
#   'highly',
#   'unlikely',
#   'person',
#   'based',
#   'espi',
#   'bank',
#   'group',
#   'anti_money_laundering',
#   'countering_financing',
#   'terrorism',
#   'procedures',
#   'dated'],
#  ['mismatch', 'id', 'number', 'nric'],
#  ['mismatch', 'identification'],
#  ['mismatch', 'full', 'name'],
#  ['match',
#   'date',
#   'birth',
#   'dob',
#   'match',
#   'id',
#   'number',
#   'nric',
#   'match',
#   'gender'],
#  ['mismatch',
#   'relationship',
#   'customer',
#   'exit',
#   'relationship',
#   'bank',
#   'product_facilities_available',
#   'unique_identifier',
#   'information',
#   'available',
#   'watch',
#   'person',
#   'conclude',
#   'individual',
#   'customer',
#   'want',
#   'open',
#   'account_fresh_kycecdd',
#   'supporting',
#   'document',
#   'need_presented_branches'],
#  ['agree_makers', 'ision', 'mismatch', 'id', 'number', 'nric'],
#  ['match', 'name', 'gender', 'dob', 'id', 'nationality'],
#  ['match', 'date', 'birth', 'dob', 'passport', 'number'],
#  ['mismatch', 'full', 'name', 'sound', 'similar', 'edms'],
#  ['mismatch',
#   'full',
#   'name',
#   'native',
#   'name',
#   'chinese',
#   'character',
#   'difference',
#   'comparison',
#   'made',
#   'customers',
#   'official',
#   'document',
#   'watchperson',
#   'info',
#   'world',
#   'check',
#   'refer',
#   'world',
#   'check',
#   'uco'],
#  ['match', 'name', 'nric'],
#  ['match', 'name', 'nric', 'gender'],
#  ['mismatch', 'fathers', 'name', 'refer'],
#  ['mismatch', 'id', 'number', 'nric'],
#  ['match', 'id', 'number', 'nric', 'date', 'birth', 'dob', 'gender'],
#  ['mismatch',
#   'id',
#   'number',
#   'nric',
#   'dob',
#   'full',
#   'name',
#   'sound',
#   'similar'],
#  ['mismatch',
#   'full',
#   'name',
#   'native',
#   'name',
#   'character',
#   'difference',
#   'comparison',
#   'made',
#   'customers',
#   'official',
#   'document',
#   'passport',
#   'copy',
#   'uco',
#   'watchpersons',
#   'name',
#   'refinitive'],
#  ['mismatch',
#   'year',
#   'birth',
#   'yob',
#   'according',
#   'worldcheck',
#   'watchperson',
#   'born',
#   'either',
#   'inferred',
#   'inferred'],
#  ['match',
#   'full',
#   'name',
#   'date',
#   'birth',
#   'dob',
#   'id',
#   'number',
#   'passport',
#   'number'],
#  ['mismatch', 'nric', 'dob'],
#  ['mismatch',
#   'id',
#   'number',
#   'nric',
#   'dob',
#   'full',
#   'name',
#   'sound',
#   'similar'],
#  ['mismatch',
#   'fathers',
#   'name',
#   'refer',
#   'uco',
#   'customers',
#   'fathers',
#   'name',
#   'available',
#   'customers',
#   'copy',
#   'passport',
#   'meanwhile',
#   'per',
#   'world',
#   'check',
#   'watchpersons',
#   'fathers',
#   'name',
#   'different',
#   'compared',
#   'customers',
#   'hence',
#   'highly',
#   'unlikely',
#   'customer',
#   'watchperson',
#   'person'],
#  ['match', 'full', 'name', 'id', 'number', 'nric', 'date', 'birth', 'dob'],
#  ['mismatch', 'date', 'birth', 'dob'],
#  ['match', 'name', 'gender', 'dob', 'nationality', 'id', 'number', 'nric'],
#  ['mismatch',
#   'full',
#   'name',
#   'sound',
#   'structurennas',
#   'per',
#   'amla',
#   'full',
#   'name',
#   'ruled',
#   'name',
#   'mismatch',
#   'though',
#   'name',
#   'close',
#   'match',
#   'eg',
#   'onetwo',
#   'different',
#   'characters',
#   'sound'],
#  ['match', 'id', 'number', 'nric'],
#  ['match', 'id', 'number', 'nric'],
#  ['mismatch',
#   'year',
#   'birth',
#   'yob',
#   'watchperson',
#   'born',
#   'based',
#   'world',
#   'check'],
#  ['match', 'full', 'name', 'date', 'birth', 'dob', 'id', 'number', 'nric'],
#  ['mismatch', 'full', 'name', 'structure'],
#  ['mismatch', 'full', 'name', 'sound', 'similar', 'name', 'structure'],
#  ['mismatch', 'date', 'birth', 'dob', 'watchperson', 'ismail'],
#  ['matched', 'nric'],
#  ['mismatch', 'full', 'name', 'sound', 'similar'],
#  ['mismatch',
#   'year',
#   'birth',
#   'yob',
#   'watchperson',
#   'yob',
#   'per',
#   'worldcheck',
#   'inferred',
#   'inferred'],
#  ['mismatch', 'year', 'birth', 'yob'],
#  ['alert', 'closed', 'hit_fico_previously'],
#  ['mismatch', 'full', 'name', 'sound', 'similar'],
#  ['match', 'name', 'gender', 'dob', 'nric', 'nationality'],
#  ['mismatch',
#   'year',
#   'birth',
#   'yob',
#   'watchperson',
#   'born',
#   'based',
#   'world',
#   'check'],
#  ['mismatch',
#   'full',
#   'name',
#   'chinese',
#   'native',
#   'character',
#   'differ',
#   'based',
#   'world',
#   'check',
#   'aliases',
#   'vs',
#   'passport',
#   'copy',
#   'customer',
#   'uploaded',
#   'uco'],
#  ['match',
#   'name',
#   'gender',
#   'id',
#   'number',
#   'date',
#   'birth',
#   'dob',
#   'nationality'],
#  ['mismatched', 'yob', 'watch', 'person', 'yob', 'info', 'refinitiv'],
#  [],
#  ['mismatch',
#   'full',
#   'name',
#   'native',
#   'name',
#   'character',
#   'difference',
#   'comparison',
#   'made',
#   'customers',
#   'official',
#   'document',
#   'passport',
#   'copy',
#   'edms',
#   'watchpersons',
#   'name',
#   'refinitiv'],
#  ['mismatch', 'year', 'birth', 'yob', 'watchperson', 'born'],
#  ['mismatched', 'nric'],
#  ['match', 'name', 'gender', 'nric'],
#  ['match',
#   'full',
#   'name',
#   'gender',
#   'nationality',
#   'date',
#   'birth',
#   'dob',
#   'id',
#   'number',
#   'passport',
#   'number'],
#  ['mismatch', 'year', 'birth', 'yob'],
#  ['mismatch', 'date', 'birth', 'dob', 'passport', 'number'],
#  ['mismatch', 'full', 'name', 'structure', 'actions'],
#  ['mismatch',
#   'fathers',
#   'name',
#   'difference',
#   'fathers',
#   'name',
#   'comparison',
#   'made',
#   'customers',
#   'fathers',
#   'name',
#   'bank',
#   'kyc',
#   'uco',
#   'watchpersons',
#   'fathers',
#   'name',
#   'refinitive'],
#  [],
#  ['mismatch',
#   'year',
#   'birth',
#   'yob',
#   'watchpersons',
#   'yob',
#   'refinitiv',
#   'worldcheck'],
#  ['match', 'id', 'full', 'name'],
#  ['mismatch',
#   'id',
#   'number',
#   'nric',
#   'watch',
#   'person',
#   'pep',
#   'related',
#   'known',
#   'tan',
#   'sri',
#   'ali_hamsa',
#   'pep',
#   'spouse',
#   'eased',
#   'deputy',
#   'chairman',
#   'johor',
#   'corporation',
#   'soe',
#   'reported',
#   'reported',
#   'independent',
#   'non',
#   'executive',
#   'chairman',
#   'editor_kulim',
#   'malaysia',
#   'berhad',
#   'soe',
#   'reported',
#   'reported',
#   'chairman',
#   'bcb',
#   'bhd',
#   'reported',
#   'executive',
#   'director',
#   'capital',
#   'bhd',
#   'reported',
#   'reported',
#   'independent',
#   'non',
#   'executive',
#   'director',
#   'yb_ventures',
#   'bhd',
#   'reported',
#   'reported',
#   'eased',
#   'watch',
#   'person',
#   'puan_sri_rohani',
#   'also',
#   'known',
#   'puan_sri',
#   'datuk_seri',
#   'rohani_parkash',
#   'found',
#   'world',
#   'check',
#   'profile',
#   'id',
#   'review',
#   'host',
#   'cif',
#   'puan_sri',
#   'datuk_seri',
#   'rohani_parkash',
#   'nric',
#   'related',
#   'relation',
#   'ali_hamsa',
#   'inqcrel',
#   'cif',
#   'nric',
#   'ar',
#   'compressedpdf'],
#  ['mismatch', 'id', 'number', 'nric'],
#  ['mismatch',
#   'full',
#   'name',
#   'native',
#   'name',
#   'character',
#   'difference',
#   'uco',
#   'documenttype_pp',
#   'refinitiv'],
#  ['mismatch',
#   'customer',
#   'worked',
#   'manufacturing',
#   'labourers',
#   'hence',
#   'reflects',
#   'pep'],
#  ['mismatch',
#   'year',
#   'birth',
#   'yob',
#   'watchpersons',
#   'yob',
#   'refinitiv',
#   'worldcheck'],
#  ['match', 'id', 'number', 'nric', 'full', 'name'],
#  ['mismatch', 'date', 'birth', 'dob', 'passport', 'number'],
#  ['mismatched',
#   'profile',
#   'customer',
#   'manufacturing',
#   'labourers',
#   'watch',
#   'person',
#   'pep',
#   'occupation',
#   'person',
#   'shows',
#   'huge_gap'],
#  ['mismatch',
#   'yobage',
#   'comparison',
#   'made',
#   'customers',
#   'yob',
#   'bank',
#   'kyc',
#   'uco',
#   'watchpersons',
#   'yob',
#   'refinitiv'],
#  ['mismatch',
#   'year',
#   'birth',
#   'yob',
#   'watchlist',
#   'yob',
#   'refer',
#   'world',
#   'check'],
#  ['mismatch',
#   'full',
#   'name',
#   'native',
#   'name',
#   'character',
#   'difference',
#   'world',
#   'check',
#   'passport',
#   'image',
#   'per',
#   'dms',
#   'uco'],
#  ['match', 'name', 'id', 'number', 'nric'],
#  ['match', 'full', 'name', 'id', 'number', 'date', 'birth'],
#  ['mismatch',
#   'yobage',
#   'comparison',
#   'made',
#   'customers',
#   'yob',
#   'bank',
#   'kyc',
#   'uco',
#   'watchpersons',
#   'yob',
#   'refinitive'],
#  ['match',
#   'name',
#   'gender',
#   'date',
#   'birth',
#   'id',
#   'number',
#   'passport',
#   'number',
#   'nationality'],
#  ['match',
#   'id',
#   'number',
#   'nric',
#   'full',
#   'name',
#   'gender',
#   'date',
#   'birth',
#   'dob'],
#  ['mismatch', 'full', 'name', 'sound', 'similar'],
#  ['match',
#   'name',
#   'gender',
#   'date',
#   'birth',
#   'dob',
#   'nationality',
#   'id',
#   'number',
#   'nric'],
#  ['mismatch',
#   'year',
#   'birth',
#   'yob',
#   'based',
#   'refinitiv',
#   'watch',
#   'persons',
#   'year',
#   'birth'],
#  ['mismatch',
#   'year',
#   'birth',
#   'yob',
#   'watchperson',
#   'yob',
#   'per',
#   'worldcheck',
#   'inferred',
#   'inferred'],
#  ['mismatch',
#   'id',
#   'number',
#   'nric',
#   'watchperson',
#   'nric',
#   'refer',
#   'gcif',
#   'upon',
#   'checking',
#   'personal',
#   'current',
#   'account',
#   'credited',
#   'transactions',
#   'personal',
#   'current',
#   'account',
#   'belong',
#   'ic',
#   'refer',
#   'gcif'],
#  ['mismatch',
#   'year',
#   'birth',
#   'yob',
#   'watchlist',
#   'yob',
#   'refer',
#   'world',
#   'check'],
#  ['mismatch', 'date', 'birth', 'dob'],
#  ['mismatch',
#   'full',
#   'name',
#   'per',
#   'amla',
#   'full',
#   'name',
#   'ruled',
#   'name',
#   'mismatch',
#   'though',
#   'name',
#   'close',
#   'match',
#   'eg',
#   'onetwo',
#   'different',
#   'characters',
#   'sound',
#   'similar',
#   'highly',
#   'unlikely',
#   'person'],
#  ['mismatch', 'year', 'birth', 'yob', 'watchperson', 'born'],
#  ['match', 'id', 'number', 'nric', 'match', 'date', 'birth', 'dob'],
#  ['match', 'id', 'number', 'nric'],
#  ['mismatch',
#   'year',
#   'birth',
#   'yobage',
#   'comparison',
#   'made',
#   'customers',
#   'yob',
#   'bank',
#   'kyc',
#   'uco',
#   'watchpersons',
#   'yob',
#   'refinitive'],
#  ['mismatch',
#   'year',
#   'birth',
#   'yob',
#   'watchpersons',
#   'yob',
#   'refinitiv',
#   'worldcheck'],
#  ['mismatch',
#   'year',
#   'birth',
#   'yob',
#   'watchlist',
#   'yob',
#   'refer',
#   'world',
#   'check'],
#  ['mismatched',
#   'profile',
#   'customer',
#   'manufacturing',
#   'labourers',
#   'watch',
#   'person',
#   'pep',
#   'occupation',
#   'person',
#   'shows',
#   'huge_gap'],
#  ['match',
#   'id',
#   'number',
#   'nric',
#   'full',
#   'name',
#   'gender',
#   'date',
#   'birth',
#   'dob'],
#  ['match', 'name', 'gender', 'dob', 'nric'],
#  ['match', 'nric'],
#  ['mismatch', 'id', 'number', 'nric', 'dob'],
#  ['matched', 'name', 'id', 'dob'],
#  ['mismatch',
#   'year',
#   'birth',
#   'yob',
#   'watchpersons',
#   'yob',
#   'refinitiv',
#   'worldcheck'],
#  ['mismatch',
#   'full',
#   'name',
#   'native',
#   'name',
#   'character',
#   'difference',
#   'customer',
#   'watchperson',
#   'different',
#   'characters',
#   'chinese',
#   'name',
#   'edms',
#   'worldcheck'],
#  ['match', 'full', 'name', 'date', 'birth', 'dob', 'gender', 'nationality'],
#  ['name', 'matched'],
#  [],
#  ['match', 'name', 'id', 'number', 'passport', 'date', 'birth', 'dob'],
#  ['mismatch',
#   'year',
#   'birth',
#   'yob',
#   'watchlist',
#   'yob',
#   'refer',
#   'world',
#   'check'],
#  [],
#  ['match',
#   'full',
#   'name',
#   'date',
#   'birth',
#   'dob',
#   'gender',
#   'id',
#   'number',
#   'nricpriy',
#   'id'],
#  ['match', 'name', 'gender', 'date', 'birth', 'dob', 'id', 'number', 'nric'],
#  ['mismatch',
#   'year',
#   'birth',
#   'yob',
#   'watchperson',
#   'yob',
#   'per',
#   'world',
#   'check'],
#  ['mismatch',
#   'customer',
#   'worked',
#   'mining',
#   'construction',
#   'labourers',
#   'hence',
#   'reflects',
#   'pep'],
#  ['mismatch', 'nric', 'dob'],
#  ['mismatched',
#   'dob',
#   'nric',
#   'gcif',
#   'watch',
#   'person',
#   'datin_seri',
#   'nric',
#   'dob',
#   'gcif',
#   'per',
#   'search',
#   'uco',
#   'base'],
#  ['name', 'mismatch'],
#  ['mismatch',
#   'year',
#   'birth',
#   'yob',
#   'watchperson',
#   'yob',
#   'per',
#   'world',
#   'check'],
#  ['mismatch', 'year', 'birth', 'yob', 'refer', 'world', 'check'],
#  ['mismatch', 'nric', 'number'],
#  ['match', 'id', 'number', 'nric'],
#  ['match', 'name', 'id', 'number', 'nric'],
#  ['match', 'name', 'gender', 'nationality', 'nric'],
#  ['match', 'name', 'date', 'birthdob'],
#  ['match', 'name', 'id', 'number', 'nricdob', 'gender', 'nationality'],
#  ['match',
#   'full',
#   'name',
#   'nric',
#   'number',
#   'date',
#   'birth',
#   'year',
#   'birth',
#   'gender',
#   'nationality'],
#  ['mismatch',
#   'year',
#   'birth',
#   'yob',
#   'watchpersons',
#   'yob',
#   'refinitiv',
#   'worldcheck'],
#  ['mismatch',
#   'full',
#   'name',
#   'native',
#   'name',
#   'character',
#   'difference',
#   'check',
#   'passport',
#   'dms',
#   'trinity'],
#  ['match', 'id', 'number', 'nric', 'date', 'birth', 'dob', 'full', 'name'],
#  ['mismatch',
#   'year',
#   'birth',
#   'yob',
#   'refer',
#   'world',
#   'check',
#   'report',
#   'inferred',
#   'inferred'],
#  ['mismatch',
#   'full',
#   'name',
#   'native',
#   'name',
#   'chinese',
#   'character',
#   'difference',
#   'comparison',
#   'made',
#   'customers',
#   'official',
#   'document',
#   'watchperson',
#   'info',
#   'world',
#   'check',
#   'refer',
#   'world',
#   'check',
#   'edms'],
#  ['product_facilities_available',
#   'unique_identifier',
#   'information',
#   'available',
#   'watch',
#   'person',
#   'conclude',
#   'individual',
#   'customer',
#   'want',
#   'open',
#   'account_fresh_kycecdd',
#   'supporting_documents',
#   'need_presented_branches'],
#  ['mismatch',
#   'yob',
#   'watchpersons',
#   'yob',
#   'watchperson',
#   'years',
#   'old',
#   'ketua',
#   'dewan',
#   'ulamak',
#   'ditentang',
#   'calon',
#   'di',
#   'jasin'],
#  ['match',
#   'name',
#   'gender',
#   'nationality',
#   'adverse',
#   'news',
#   'immaterial',
#   'related',
#   'aml'],
#  ['match',
#   'id',
#   'number',
#   'passport',
#   'number',
#   'match',
#   'date',
#   'birth',
#   'dob',
#   'match',
#   'full',
#   'name'],
#  [],
#  ['customer',
#   'dob',
#   'fall',
#   'within',
#   'watch',
#   'person',
#   'possible',
#   'dob',
#   'range',
#   'within'],
#  ['match',
#   'name',
#   'gender',
#   'id',
#   'number',
#   'nric',
#   'date',
#   'birth',
#   'dob',
#   'nationality'],
#  ['mismatch', 'full', 'name', 'sound', 'similar'],
#  ['match', 'name', 'dob', 'passport'],
#  ['mismatch',
#   'full',
#   'name',
#   'native',
#   'name',
#   'chinese',
#   'character',
#   'difference',
#   'comparison',
#   'made',
#   'customers',
#   'official',
#   'document',
#   'watchperson',
#   'info',
#   'world',
#   'check',
#   'refer',
#   'world',
#   'check',
#   'edms'],
#  ['mismatch',
#   'year',
#   'birth',
#   'yob',
#   'watchperson',
#   'yob',
#   'per',
#   'world',
#   'check'],
#  ['mismatch', 'yob', 'per', 'refinitiv', 'watchperson', 'born'],
#  ['match', 'name', 'date', 'birth', 'dob'],
#  ['match',
#   'name',
#   'gender',
#   'id',
#   'number',
#   'passport',
#   'number',
#   'date',
#   'birth',
#   'dob',
#   'nationality'],
#  ['mismatch',
#   'year',
#   'birth',
#   'yob',
#   'watch',
#   'person',
#   'member',
#   'house',
#   'representatives',
#   'jasin',
#   'member',
#   'parti_islam_se',
#   'malaysia',
#   'pas',
#   'member',
#   'perikatan_nasional_pn',
#   'born',
#   'dob',
#   'info',
#   'background',
#   'found',
#   'per',
#   'link',
#   'ismail',
#   'murabbi_tuan_guru_hj',
#   'zulkifli_sudah_lama_dikenali',
#   'rakyat',
#   'tangga_batu'],
#  ['mismatch',
#   'year',
#   'birth',
#   'yob',
#   'refer',
#   'world',
#   'check',
#   'watchpersons',
#   'yob',
#   'inferred',
#   'inferred'],
#  ['mismatch', 'id', 'number', 'nric'],
#  ['mismatch', 'full', 'name', 'sound', 'similar'],
#  ['mismatch', 'year', 'birth', 'yob'],
#  ['match', 'full', 'name', 'id', 'number', 'nric'],
#  ['mismatch', 'year', 'birth', 'yob', 'watchperson', 'born'],
#  ['mismatch', 'id', 'number', 'nric'],
#  ['mismatch',
#   'year',
#   'birth',
#   'yob',
#   'watchpersons',
#   'yob',
#   'refinitiv',
#   'worldcheck'],
#  ['match',
#   'full',
#   'name',
#   'match',
#   'gender',
#   'match',
#   'date',
#   'birth',
#   'dob',
#   'match',
#   'id',
#   'number',
#   'nric'],
#  ['match', 'dob', 'id', 'number', 'passport', 'number'],
#  ['mismatch',
#   'year',
#   'birth',
#   'yob',
#   'watchpersons',
#   'yob',
#   'refinitiv',
#   'worldcheck'],
#  ['match', 'full', 'name', 'date', 'birth'],
#  ['mismatch', 'full', 'name', 'sound', 'similar'],
#  ['match',
#   'name',
#   'gender',
#   'date',
#   'birth',
#   'dob',
#   'nationality',
#   'id',
#   'number',
#   'nric'],
#  ['mismatch', 'year', 'birth', 'yob'],
#  ['mismatch',
#   'yobage',
#   'comparison',
#   'made',
#   'customers',
#   'yob',
#   'bank',
#   'kyc',
#   'uco',
#   'watchpersons',
#   'yob',
#   'refinitive',
#   'watchpersons',
#   'yob'],
#  ['match', 'full', 'name', 'date', 'birth', 'dob', 'gender', 'priy', 'id'],
#  ['match', 'name', 'nric'],
#  ['mismatch',
#   'full',
#   'name',
#   'native',
#   'name',
#   'chinese',
#   'character',
#   'difference',
#   'comparison',
#   'made',
#   'customers',
#   'official',
#   'document',
#   'passport',
#   'uco',
#   'watchperson',
#   'info',
#   'world',
#   'check',
#   'refer',
#   'world',
#   'check',
#   'uco'],
#  ['mismatch',
#   'year',
#   'birth',
#   'yob',
#   'watchperson',
#   'yob',
#   'per',
#   'world',
#   'check'],
#  ['mismatch', 'yob', 'per', 'refinitiv', 'watchperson', 'born'],
#  ['mismatch',
#   'id',
#   'number',
#   'nric',
#   'according',
#   'uco',
#   'search',
#   'watchpersons',
#   'nric',
#   'watchpersons',
#   'gcif'],
#  ['mismatch',
#   'full',
#   'name',
#   'structure',
#   'watchpersons',
#   'name',
#   'mohamad',
#   'razak',
#   'per',
#   'link',
#   'directors'],
#  ['mismatch', 'full', 'name', 'sound', 'similar', 'amc', 'csc', 'mr'],
#  ['customer',
#   'common',
#   'name',
#   'native',
#   'country',
#   'lack_unique_identifiers_hits',
#   'generated_us_meaningfully',
#   'review',
#   'hits',
#   'also',
#   'indicator',
#   'suggest',
#   'customer',
#   'person',
#   'potential_matches_risk',
#   'based',
#   'approach',
#   'customer',
#   'tagged',
#   'high_risk_solely',
#   'based',
#   'potential',
#   'name',
#   'match',
#   'bulk',
#   'closure',
#   'alert',
#   'assignment'],
#  ['mismatch',
#   'year',
#   'birth',
#   'yob',
#   'watchpersons',
#   'yob',
#   'refinitiv',
#   'worldcheck'],
#  ['mismatch',
#   'fathers',
#   'name',
#   'difference',
#   'fathers',
#   'name',
#   'comparison',
#   'made',
#   'customers',
#   'official',
#   'document',
#   'passport',
#   'uco',
#   'watchperson',
#   'info',
#   'refer',
#   'uco'],
#  ['mismatch', 'full', 'name', 'name', 'sound', 'similar'],
#  ['mismatch',
#   'yobage',
#   'comparison',
#   'made',
#   'customers',
#   'yob',
#   'bank',
#   'kyc',
#   'uco',
#   'watchpersons',
#   'yob',
#   'refinitive',
#   'watchpersons',
#   'yob'],
#  ['match',
#   'full',
#   'name',
#   'match',
#   'date',
#   'birth',
#   'dob',
#   'match',
#   'id',
#   'number',
#   'nric'],
#  ['mismatch', 'year', 'birth', 'yob', 'watchperson', 'born'],
#  ['mismatched',
#   'profile',
#   'customer',
#   'agricultural',
#   'forestry',
#   'farming',
#   'fishery',
#   'labourers',
#   'watch',
#   'person',
#   'pep',
#   'occupation',
#   'person',
#   'shows',
#   'huge_gap'],
#  ['customer',
#   'dob',
#   'fall',
#   'within',
#   'watch',
#   'person',
#   'possible',
#   'dob',
#   'range',
#   'within',
#   'refer',
#   'cscdd',
#   'tool'],
#  ['mismatch', 'id', 'number', 'nric', 'gbffspfquickidf'],
#  ['mismatch', 'id', 'number', 'nric', 'mismatch', 'date', 'birth', 'dob'],
#  ['mismatch',
#   'full',
#   'name',
#   'name',
#   'sound',
#   'similar',
#   'though',
#   'name',
#   'close',
#   'match',
#   'eg',
#   'one',
#   'two',
#   'different',
#   'characters',
#   'sound',
#   'similar',
#   'highly',
#   'unlikely',
#   'person'],
#  ['mismatch',
#   'customer',
#   'worked_cleaners_helpers',
#   'hence',
#   'reflected',
#   'pep'],
#  ['mismatch',
#   'id',
#   'number',
#   'nric',
#   'per',
#   'checking',
#   'uco',
#   'watchperson',
#   'rozina',
#   'rahman',
#   'banks',
#   'customer',
#   'nric',
#   'gcif',
#   'plus',
#   'per',
#   'uco',
#   'watchperson',
#   'works',
#   'administrative',
#   'commercial',
#   'manager',
#   'bpmb',
#   'malaysia',
#   'development',
#   'bank',
#   'income',
#   'range',
#   'rm',
#   'rm',
#   'similar',
#   'watchpersons',
#   'profile',
#   'chief',
#   'risk',
#   'officer',
#   'bank',
#   'pembangunan',
#   'malaysia',
#   'berhad',
#   'soe',
#   'thus',
#   'highly',
#   'unlikely',
#   'person'],
#  ['match', 'name', 'gender', 'date', 'birth', 'dob', 'id', 'number', 'nric'],
#  ['mismatch', 'year', 'birth', 'yob'],
#  ['mismatch', 'full', 'name'],
#  ['match', 'name', 'dob', 'gender', 'nric'],
#  ['mismatch', 'yob', 'watchperson', 'born', 'years', 'old'],
#  ['mismatch',
#   'full',
#   'name',
#   'name',
#   'sound',
#   'similar',
#   'though',
#   'name',
#   'close',
#   'match',
#   'eg',
#   'one',
#   'two',
#   'different',
#   'characters',
#   'sound',
#   'similar',
#   'highly',
#   'unlikely',
#   'person',
#   'based',
#   'espi',
#   'bank',
#   'group',
#   'anti_money_laundering',
#   'countering_financing',
#   'terrorism',
#   'procedures',
#   'dated'],
#  ['mismatch', 'date', 'birth'],
#  ['invalid', 'hit', 'watch', 'list', 'item', 'deleted'],
#  ['mismatch', 'full', 'name', 'structure'],
#  [],
#  ['mismatch',
#   'eased',
#   'per',
#   'world',
#   'check',
#   'watch',
#   'person',
#   'reported',
#   'eased',
#   'watch',
#   'person',
#   'location',
#   'kag',
#   'selangor',
#   'seberang_perai_pulau_pinang',
#   'pep',
# ...
#   'fall',
#   'within',
#   'watch',
#   'person',
#   'possible',
#   'dob',
#   'range',
#   'within'],
#  ['mismatch', 'year', 'birth', 'yob', 'watchperson', 'born'],
#  ['mismatch', 'full', 'name', 'name', 'sound', 'similar'],
#  ['mismatched', 'yob', 'watch', 'person', 'yob', 'info', 'refinitiv'],
#  ['mismatch',
#   'id',
#   'number',
#   'nric',
#   'ucif',
#   'gcif',
#   'watchpersons',
#   'nric',
#   'based',
#   'checking',
#   'watchperson',
#   'one',
#   'bank',
#   'customer',
#   'details',
#   'employment',
#   'copy',
#   'nric',
#   'dms',
#   'match',
#   'information',
#   'google',
#   'world',
#   'check',
#   'refer',
#   'link',
#   'hashim'],
#  ['customer',
#   'dob',
#   'fall',
#   'within',
#   'watch',
#   'person',
#   'possible',
#   'dob',
#   'range',
#   'within'],
#  ['mismatch', 'year', 'birth', 'yob', 'watchperson', 'born'],
#  ['mismatch',
#   'year',
#   'birth',
#   'yob',
#   'watchlist',
#   'yob',
#   'refer',
#   'world',
#   'check'],
#  ['mismatch',
#   'year',
#   'birth',
#   'yob',
#   'refer',
#   'world',
#   'check',
#   'watchpersons',
#   'year',
#   'birth',
#   'inferred',
#   'inferred'],
#  ['mismatch',
#   'year',
#   'birth',
#   'yobage',
#   'watchperson',
#   'reported',
#   'age',
#   'yob',
#   'refer',
#   'link',
#   'pdf'],
#  ['mismatch',
#   'year',
#   'birth',
#   'yob',
#   'watch',
#   'persons',
#   'yob',
#   'worldcheck',
#   'inferred',
#   'inferred'],
#  ['matched', 'name', 'dob'],
#  ['mismatch',
#   'full',
#   'name',
#   'sound',
#   'similarfathers',
#   'name',
#   'ucodocumenttype_idd',
#   'trinity'],
#  ['mismatch', 'id', 'number', 'nric'],
#  ['mismatch',
#   'yobage',
#   'comparison',
#   'made',
#   'customers',
#   'yob',
#   'bank',
#   'kyc',
#   'uco',
#   'watchpersons',
#   'yob',
#   'refinitive',
#   'watchpersons',
#   'yob'],
#  ['customer',
#   'dob',
#   'fall',
#   'within',
#   'watch',
#   'person',
#   'possible',
#   'dob',
#   'range',
#   'within'],
#  ['match', 'full', 'name', 'match', 'nric', 'match', 'date', 'birth', 'dob'],
#  ['mismatch',
#   'id',
#   'number',
#   'citizenship',
#   'number',
#   'comparison',
#   'made',
#   'customers',
#   'citizenship',
#   'number',
#   'bank',
#   'kyc',
#   'uco',
#   'watchpersons',
#   'citizenship',
#   'number',
#   'refinitive'],
#  ['mismatch',
#   'year',
#   'birth',
#   'yob',
#   'watchpersons',
#   'yob',
#   'refinitiv',
#   'worldcheck'],
#  ['mismatch',
#   'id',
#   'number',
#   'nric',
#   'wl',
#   'ic',
#   'gcif',
#   'account',
#   'customer',
#   'received',
#   'monthly',
#   'allowance',
#   'koperasi_muslimin',
#   'malaysia',
#   'wl',
#   'setiausaha',
#   'koperasi_muslimin_korporat',
#   'noor',
#   'mohamad'],
#  ['match', 'id', 'number', 'nric', 'name', 'gender', 'dob'],
#  ['customer',
#   'dob',
#   'fall',
#   'within',
#   'watch',
#   'person',
#   'possible',
#   'dob',
#   'range',
#   'within'],
#  ['mismatch',
#   'full',
#   'name',
#   'native',
#   'name',
#   'character',
#   'difference',
#   'comparison',
#   'made',
#   'customers',
#   'official',
#   'document',
#   'old',
#   'passport',
#   'ed',
#   'dms',
#   'watchpersons',
#   'name',
#   'refinitive'],
#  ['match',
#   'full',
#   'name',
#   'match',
#   'date',
#   'birth',
#   'dob',
#   'match',
#   'id',
#   'number',
#   'passport',
#   'match',
#   'nationality'],
#  ['mismatch',
#   'year',
#   'birth',
#   'yob',
#   'comparison',
#   'made',
#   'customers',
#   'available',
#   'information',
#   'uco',
#   'watchperson',
#   'info',
#   'refinitiv',
#   'world',
#   'check',
#   'wls',
#   'yob'],
#  ['mismatched',
#   'profile',
#   'customer',
#   'gardeners_horticultural_nursery_growers',
#   'watch',
#   'person',
#   'pep'],
#  ['mismatch',
#   'full',
#   'name',
#   'sound',
#   'similar',
#   'refer',
#   'bank',
#   'group',
#   'anti_money_laundering',
#   'countering_financing',
#   'terrorism',
#   'procedures_sub_section_ai',
#   'pg',
#   'ruled',
#   'name',
#   'mismatch',
#   'though',
#   'name',
#   'close',
#   'match',
#   'eg',
#   'onetwo',
#   'different',
#   'characters',
#   'sound',
#   'similar',
#   'highly',
#   'unlikely',
#   'person'],
#  ['mismatched', 'yob', 'watch', 'person', 'yob', 'info', 'refinitiv'],
#  ['match', 'full', 'name', 'date', 'birth', 'id', 'number', 'nric'],
#  ['customer',
#   'dob',
#   'fall',
#   'within',
#   'watch',
#   'person',
#   'possible',
#   'dob',
#   'range',
#   'within'],
#  ['mismatched', 'yob', 'watch', 'person', 'yob', 'info', 'refinitiv'],
#  ['mismatch',
#   'year',
#   'birth',
#   'yob',
#   'refer',
#   'world',
#   'check',
#   'report',
#   'inferred',
#   'inferred'],
#  ['mismatch',
#   'year',
#   'birth',
#   'yob',
#   'refer',
#   'world',
#   'check',
#   'report',
#   'inferred',
#   'inferred'],
#  ['mismatch',
#   'id',
#   'number',
#   'nric',
#   'watchperson',
#   'banks',
#   'customer',
#   'gcif',
#   'nric',
#   'per',
#   'uco',
#   'customer',
#   'demographic',
#   'senior',
#   'government',
#   'official',
#   'kem',
#   'pembangunan',
#   'usahawan',
#   'dan',
#   'koperasi',
#   'identical',
#   'watchpersons',
#   'profile',
#   'deputy',
#   'secretary',
#   'general',
#   'policy',
#   'monitoring',
#   'ministry',
#   'entrepreneur',
#   'development',
#   'cooperatives'],
#  ['mismatch', 'year', 'birth', 'yob', 'refer', 'worldcheck'],
#  ['mismatch', 'year', 'birth', 'yob', 'watchperson', 'born'],
#  ['mismatch', 'full', 'name', 'name', 'structure'],
#  ['mismatch',
#   'year',
#   'birth',
#   'yob',
#   'watchlist',
#   'yob',
#   'refer',
#   'world',
#   'check'],
#  ['mismatch', 'id', 'number', 'nric', 'mismatch', 'date', 'birth', 'dob'],
#  ['mismatch',
#   'yobage',
#   'comparison',
#   'made',
#   'customers',
#   'yob',
#   'bank',
#   'kyc',
#   'uco',
#   'watchpersons',
#   'yob',
#   'refinitive',
#   'watchpersons',
#   'yob'],
#  ['mismatch',
#   'full',
#   'name',
#   'native',
#   'name',
#   'character',
#   'difference',
#   'comparison',
#   'made',
#   'customers',
#   'official',
#   'document',
#   'passport',
#   'copy',
#   'uco',
#   'dms',
#   'watchpersons',
#   'name',
#   'refinitive'],
#  ['mismatch', 'year', 'birth', 'yob', 'watch', 'person', 'born'],
#  ['mismatch',
#   'year',
#   'birth',
#   'yob',
#   'watchpersons',
#   'yob',
#   'refinitiv',
#   'worldcheck'],
#  ['match',
#   'full',
#   'name',
#   'match',
#   'date',
#   'birth',
#   'dob',
#   'match',
#   'id',
#   'number',
#   'passport',
#   'match',
#   'nationality',
#   'customer',
#   'watchperson',
#   'holding',
#   'iranian',
#   'citizenship',
#   'based',
#   'comparison',
#   'customers',
#   'uco',
#   'watchperson',
#   'detail',
#   'likely',
#   'customer',
#   'watchperson',
#   'person'],
#  ['match', 'name', 'gender', 'id', 'number', 'date', 'birth', 'dob'],
#  ['match', 'name', 'passport', 'number', 'dob', 'nationality'],
#  ['mismatch',
#   'year',
#   'birth',
#   'yob',
#   'watchlist',
#   'yob',
#   'refer',
#   'world',
#   'check'],
#  ['match', 'name', 'gender', 'id', 'number', 'date', 'birth', 'dob'],
#  ['mismatch',
#   'fathers',
#   'name',
#   'difference',
#   'fathers',
#   'name',
#   'comparison',
#   'made',
#   'customers',
#   'fathers',
#   'name',
#   'bank',
#   'kyc',
#   'uco',
#   'watchpersons',
#   'fathers',
#   'name',
#   'refinitive'],
#  ['mismatched', 'yob', 'watch', 'person', 'yob', 'info', 'refinitiv'],
#  ['match', 'name', 'nric'],
#  ['mismatch',
#   'full',
#   'name',
#   'structure',
#   'per',
#   'world',
#   'check',
#   'watchpersons',
#   'name',
#   'salleh',
#   'ahmad'],
#  ['mismatch',
#   'year',
#   'birth',
#   'yob',
#   'per',
#   'refinitiv',
#   'world',
#   'check',
#   'watchperson',
#   'born'],
#  ['mismatch', 'year', 'birth', 'yob', 'watchperson', 'born'],
#  ['mismatch',
#   'year',
#   'birth',
#   'yob',
#   'refer',
#   'world',
#   'check',
#   'report',
#   'inferred',
#   'inferred'],
#  ['mismatch', 'date', 'birth', 'passport', 'number'],
#  ['mismatch', 'yob', 'per', 'refinitiv', 'watchperson', 'born'],
#  ['mismatch',
#   'full',
#   'name',
#   'native',
#   'name',
#   'character',
#   'difference',
#   'per',
#   'customer',
#   'passport',
#   'edms'],
#  ['mismatch',
#   'year',
#   'birth',
#   'based',
#   'customer',
#   'date',
#   'birth',
#   'unlikely',
#   'father',
#   'datuk_seri',
#   'anwar_ibrahim',
#   'datuk_seri',
#   'anwar_ibrahim',
#   'date',
#   'birth',
#   'dob'],
#  ['mismatch',
#   'id',
#   'number',
#   'nric',
#   'watchpersons',
#   'nric',
#   'based',
#   'profile',
#   'uco',
#   'works',
#   'senior',
#   'government',
#   'officer',
#   'ministry',
#   'foreign',
#   'affairs',
#   'watchpersons',
#   'ucif',
#   'gcif'],
#  ['customer',
#   'dob',
#   'fall',
#   'within',
#   'watch',
#   'person',
#   'possible',
#   'dob',
#   'range',
#   'within',
#   'refer',
#   'cscdd',
#   'tool'],
#  ['mismatch',
#   'full',
#   'name',
#   'sound',
#   'similar',
#   'mismatch',
#   'obvious',
#   'name',
#   'structure',
#   'per',
#   'link'],
#  ['mismatch',
#   'year',
#   'birth',
#   'yob',
#   'comparison',
#   'made',
#   'customers',
#   'available',
#   'information',
#   'uco',
#   'watchperson',
#   'info',
#   'refinitiv',
#   'world',
#   'check',
#   'wls',
#   'yob'],
#  ['mismatch',
#   'year',
#   'birth',
#   'yob',
#   'watchperson',
#   'yob',
#   'per',
#   'world',
#   'check'],
#  ['match', 'name', 'gender', 'id', 'number', 'nric', 'nationality'],
#  ['customer',
#   'dob',
#   'fall',
#   'within',
#   'watch',
#   'person',
#   'possible',
#   'dob',
#   'range',
#   'within',
#   'refer',
#   'cscdd',
#   'tool'],
#  ['mismatch', 'year', 'birth', 'yob', 'watchperson', 'born'],
#  ['mismatch',
#   'year',
#   'birth',
#   'yob',
#   'comparison',
#   'made',
#   'customers',
#   'available',
#   'information',
#   'uco',
#   'watchperson',
#   'info',
#   'refinitiv',
#   'world',
#   'check',
#   'wls',
#   'yob'],
#  ['mismatch',
#   'year',
#   'birth',
#   'yob',
#   'watch',
#   'person',
#   'director_silver_ridge',
#   'sdn',
#   'bhd',
#   'reported',
#   'resigned',
#   'executive',
#   'director_silver_ridge',
#   'holdings',
#   'bhd',
#   'th',
#   'years',
#   'old',
#   'yob',
#   'ridge_holdings',
#   'bhd',
#   'newssilver_ridge',
#   'holdings',
#   'bhd',
#   'announces_resignation_wong_chee',
#   'keong',
#   'executive',
#   'director'],
#  ['mismatch', 'id', 'number', 'citizenship', 'number'],
#  ['full',
#   'name',
#   'match',
#   'identifier',
#   'assessment',
#   'customer',
#   'card_product_inactive',
#   'status',
#   'recommended',
#   'exit',
#   'relationship',
#   'view',
#   'card',
#   'inactive',
#   'since',
#   'low_balance',
#   'rm'],
#  [],
#  ['match',
#   'full',
#   'name',
#   'match',
#   'date',
#   'birth',
#   'dob',
#   'match',
#   'id',
#   'number',
#   'nric',
#   'number'],
#  ['match',
#   'name',
#   'gender',
#   'date',
#   'birth',
#   'id',
#   'number',
#   'passport',
#   'number'],
#  ['mismatched', 'yob', 'watch', 'person', 'yob', 'info', 'refinitiv'],
#  ['match',
#   'full',
#   'name',
#   'passport',
#   'number',
#   'nationality',
#   'match',
#   'date',
#   'birth',
#   'dob',
#   'match',
#   'gender'],
#  ['mismatch', 'fathers', 'name', 'refer'],
#  ['mismatched', 'yob', 'watch', 'person', 'yob', 'info', 'refinitiv'],
#  ['mismatch',
#   'year',
#   'birth',
#   'yob',
#   'watchperson',
#   'yob',
#   'per',
#   'world',
#   'check'],
#  ['mismatch',
#   'year',
#   'birth',
#   'yob',
#   'watchperson',
#   'yob',
#   'per',
#   'world',
#   'check'],
#  ['mismatch', 'id', 'number', 'nric', 'dob'],
#  ['mismatch', 'id', 'number', 'nric', 'watchperson', 'nric', 'refer', 'gcif'],
#  ['alert', 'closed', 'hit_fico_previously'],
#  ['mismatch', 'date', 'birth', 'dob'],
#  ['mismatch',
#   'year',
#   'birth',
#   'yob',
#   'watchpersons',
#   'yob',
#   'refinitiv',
#   'worldcheck'],
#  ['mismatch',
#   'year',
#   'birth',
#   'yob',
#   'watchperson',
#   'yob',
#   'per',
#   'world',
#   'check'],
#  ['mismatch', 'full', 'name', 'name', 'structure'],
#  ['mismatch', 'full', 'name', 'structure'],
#  ['mismatch',
#   'year',
#   'birth',
#   'yob',
#   'per',
#   'checking',
#   'refinitiv',
#   'world',
#   'check',
#   'watchperson',
#   'yob',
#   'inferred',
#   'inferred'],
#  ['mismatch',
#   'year',
#   'birth',
#   'yob',
#   'comparison',
#   'made',
#   'customers',
#   'available',
#   'information',
#   'uco',
#   'watchperson',
#   'info',
#   'refinitiv',
#   'world',
#   'check',
#   'wls',
#   'yob'],
#  ['match',
#   'full',
#   'name',
#   'match',
#   'nric',
#   'match',
#   'year',
#   'birth',
#   'yob',
#   'match',
#   'date',
#   'birth',
#   'dob',
#   'match',
#   'gender'],
#  ['mismatch',
#   'full',
#   'name',
#   'native',
#   'name',
#   'character',
#   'difference',
#   'comparing',
#   'watchperson',
#   'customer',
#   'name',
#   'character',
#   'worldcheck',
#   'aliases',
#   'passport',
#   'copy',
#   'uco'],
#  ['match', 'name', 'gender', 'id', 'number', 'nric', 'date', 'birth', 'dob'],
#  ['match',
#   'full',
#   'name',
#   'date',
#   'birth',
#   'dob',
#   'gender',
#   'id',
#   'number',
#   'nricpriy',
#   'id'],
#  ['mismatch',
#   'year',
#   'birth',
#   'yob',
#   'watchperson',
#   'yob',
#   'per',
#   'world',
#   'check'],
#  ['mismatch',
#   'id',
#   'number',
#   'nric',
#   'watchperson',
#   'nric',
#   'ucif',
#   'watchperson',
#   'one',
#   'mbbs',
#   'customer',
#   'infomation',
#   'uco',
#   'managing',
#   'directors',
#   'chief',
#   'executives_itx',
#   'consultancy',
#   'however',
#   'nric',
#   'photo',
#   'information',
#   'dms',
#   'uco',
#   'matched',
#   'watchpersons',
#   'image',
#   'per',
#   'link',
#   'link',
#   'amin'],
#  ['mismatch',
#   'full',
#   'name',
#   'native',
#   'name',
#   'character',
#   'difference',
#   'comparison',
#   'made',
#   'customers',
#   'official',
#   'document',
#   'passport',
#   'copy',
#   'edms',
#   'watchpersons',
#   'chinese',
#   'native'],
#  ['mismatched', 'yob', 'watch', 'person', 'yob', 'info', 'refinitiv'],
#  ['mismatch', 'date', 'birth'],
#  ['mismatch',
#   'year',
#   'birth',
#   'yob',
#   'refer',
#   'world',
#   'check',
#   'report',
#   'inferred',
#   'inferred'],
#  ['mismatched', 'yob', 'watch', 'person', 'yob', 'info', 'refinitiv'],
#  ['mismatch', 'year', 'worldcheck', 'watchlist', 'yob'],
#  ['mismatch',
#   'dob',
#   'customer',
#   'dob',
#   'fall',
#   'within',
#   'watch',
#   'person',
#   'possible',
#   'dob',
#   'range',
#   'within',
#   'csc',
#   'trinity',
#   'discounting',
#   'comm',
#   'watch',
#   'person',
#   'dob',
#   'range',
#   'calculator',
#   'dated'],
#  ['mismatch',
#   'customer',
#   'worked',
#   'manufacturing',
#   'labourers',
#   'income',
#   'hence',
#   'reflects',
#   'pep'],
#  ['mismatch',
#   'year',
#   'birth',
#   'yob',
#   'based',
#   'refinitiv',
#   'watch',
#   'persons',
#   'year',
#   'birth'],
#  ['customer',
#   'dob',
#   'fall',
#   'within',
#   'watch',
#   'person',
#   'possible',
#   'dob',
#   'range',
#   'within',
#   'refer',
#   'cscdd',
#   'tool'],
#  ['mismatch',
#   'yobage',
#   'comparison',
#   'made',
#   'customers',
#   'yob',
#   'bank',
#   'kyc',
#   'uco',
#   'watchpersons',
#   'yob',
#   'refinitive',
#   'watchpersons',
#   'yob'],
#  ['mismatch',
#   'year',
#   'birth',
#   'yob',
#   'comparison',
#   'made',
#   'customers',
#   'available',
#   'information',
#   'uco',
#   'watchperson',
#   'info',
#   'refinitiv',
#   'world',
#   'check',
#   'wls',
#   'yob'],
#  ['mismatch',
#   'year',
#   'birth',
#   'yob',
#   'watch',
#   'person',
#   'yob',
#   'worldcheck',
#   'inferred',
#   'inferred'],
#  ['match', 'full', 'name', 'id', 'number', 'passport', 'date', 'birth', 'dob'],
#  ['mismatch',
#   'year',
#   'birth',
#   'yob',
#   'watchlist',
#   'yob',
#   'refer',
#   'world',
#   'check'],
#  ['mismatch',
#   'year',
#   'birth',
#   'yob',
#   'watchperson',
#   'yob',
#   'per',
#   'world',
#   'check'],
#  ['mismatch',
#   'year',
#   'birth',
#   'yob',
#   'watchlist',
#   'yob',
#   'refer',
#   'world',
#   'check'],
#  ['mismatch',
#   'full',
#   'name',
#   'chinese',
#   'native',
#   'character',
#   'differ',
#   'based',
#   'world',
#   'check',
#   'aliases',
#   'vs',
#   'passport',
#   'copy',
#   'customer',
#   'uploaded',
#   'uco'],
#  ['mismatch',
#   'id',
#   'number',
#   'nric',
#   'watchperson',
#   'banks',
#   'customer',
#   'nric',
#   'gcif',
#   'watchperson',
#   'spouse_chen_chaw',
#   'min',
#   'pep',
#   'gcif',
#   'shared_residential',
#   'address',
#   'ebpp'],
#  ['mismatch',
#   'year',
#   'birth',
#   'yob',
#   'watchlist',
#   'yob',
#   'refer',
#   'world',
#   'check'],
#  ['mismatch',
#   'fathers',
#   'name',
#   'difference',
#   'fathers',
#   'name',
#   'comparison',
#   'made',
#   'customers',
#   'official',
#   'document',
#   'uco',
#   'watchperson',
#   'info',
#   'worldcheck'],
#  ['match', 'name', 'dob', 'id', 'number', 'nric'],
#  ['mismatch',
#   'full',
#   'name',
#   'native',
#   'name',
#   'character',
#   'difference',
#   'watchpersons',
#   'native',
#   'character',
#   'name',
#   'world',
#   'check',
#   'vs',
#   'customers',
#   'native',
#   'character',
#   'name',
#   'found',
#   'uco',
#   'documenttype_idd'],
#  ['match', 'name', 'id', 'number', 'nric'],
#  ['mismatch', 'year', 'birth', 'yob', 'watchperson', 'born'],
#  ['mismatch',
#   'full',
#   'name',
#   'sound',
#   'structure',
#   'customer',
#   'rakesh_ku',
#   'watch',
#   'person',
#   'rajesh_ku',
#   'per',
#   'amla',
#   'full',
#   'name',
#   'ruled',
#   'name',
#   'mismatch',
#   'though',
#   'name',
#   'close',
#   'match',
#   'eg',
#   'onetwo',
#   'different',
#   'characters',
#   'sound',
#   'similar',
#   'highly',
#   'unlikely',
#   'person',
#   'checking',
#   'ociss',
#   'customer',
#   'listed',
#   'ociss',
#   'based',
#   'nricidpassport',
#   'number'],
#  ['match', 'id', 'number', 'nric', 'mfk', 'csc', 'mr'],
#  ...]

# %%
import spacy

# %%
# Initialize spacy 'en' model, keeping only tagger component (for efficiency)
nlp = spacy.load("en_core_web_sm", disable=['parser', 'ner'])

# Do lemmatization keeping only noun, adj, vb, adv
data_lemmatized = lemmatization(data_words_trigrams)

print(data_lemmatized[:1][0][:30])

# %%
data_lemmatized

# %%
import gensim.corpora as corpora

# Create Dictionary
id2word = corpora.Dictionary(data_lemmatized)

# Create Corpus
texts = data_lemmatized

# Term Document Frequency
corpus = [id2word.doc2bow(text) for text in texts] 

# View
print(corpus[:1][0][:30])

# %%
df_all_comments["Tokens"]=data_lemmatized
df_all_comments["id_2_feature"]=corpus

# %%
lda_model = gensim.models.LdaMulticore(corpus=corpus,
                                       id2word=id2word,
                                       num_topics=10, 
                                       random_state=100,
                                       chunksize=100,
                                       passes=10,
                                       per_word_topics=True)

# lda_model = gensim.models.ldamodel.LdaModel(corpus=corpus,
#                                        id2word=id2word,
#                                        num_topics=20, 
#                                        random_state=100,
#                                        chunksize=100,
#                                        passes=10,
                                    
#                                            alpha=0.3,
#                                            per_word_topics=True,
#                                            eta = 0.3)

# %%
# Print the Keyword in the 10 topics
pprint(lda_model.print_topics())
doc_lda = lda_model[corpus]

# %% [markdown]
# ## Latent Dirichlet Allocation[LDA]:
#
# LDA algorithm is an unsupervised learning algorithm that works on a probabilistic statistical model to discover topics that the document contains automatically. <br>
# This algorithm works on certain assumptions. The assumption is that the document was generated by picking a set of topics and picking a set of words for each topic. In other words, we can say that the document is a probability distribution over the latent topics, and topics are probability distribution over the words.
#
# Now let's understand the work methodology of LDA using Plate Diagram:
# <br>
#
# ![Smoothed_LDA.png](attachment:f941a0a0-3132-4dd6-88d8-2930d44b78c5.png)
#
#                **Plate Diagram of LDA model**
#
# The above image is taken from [Wikipedia](http://https://upload.wikimedia.org/wikipedia/commons/thumb/4/4d/Smoothed_LDA.png/377px-Smoothed_LDA.png)
#
# Here, $\alpha$ and $\beta$ are two hyperparameters that we have to initialise manually, and they symbolize per topic distribution($\alpha$) and per topic word distribution($\beta$), respectively. And **Z** is the topic for the **N**-th word in document **M**, and **W** is the specific word. We can only see W(specific words) in the documents because it is only an observable variable, and all others are latent.
#
# $\theta$ is the matrix where rows are the documents; columns are topics, and $\theta(i,j)$ represents the probability of $ith$ document containing $jth$ topic. Similarly, $\phi$ is the matrix where rows are the topics; columns are words, and $\phi(i,j)$ represents the probability of $ith$ topic containing $jth$ word. According to the distribution of $\phi$; **K** individual words are generated for the topics.
#
# With the help of this LDA, try to estimate the words that belong to each topic and find the topics in documents accordingly.

# %%
import pickle
pickle.dump(lda_model,open("lda_model_lemmatizer_bow_bi_tri.sav","wb"))

# %%
import pickle

# %%
lda_model = pickle.load(open("lda_model_lemmatizer_bow_bi_tri.sav","rb"))

# %%
# Get the top words for each topic
top_words_per_topic = []
for topic_id in range(lda_model.num_topics):
    top_words = [id2word[word_id] for word_id, prob in lda_model.get_topic_terms(topic_id, topn=10)]
    top_words_per_topic.append(top_words)

# %%
dict1={}
for i,j in zip(range(len(top_words_per_topic)),top_words_per_topic):
    dict1[i]=j

# %%
df_all_comments.reset_index(inplace=True)

# %%
df_all_comments.drop("index",axis=1,inplace=True)

# %%
# get_document_topics(corpus)
for i, doc in enumerate(corpus):
    print("Document", i+1)
    print(lda_model.get_document_topics(doc))

# %%
# Compute Perplexity
print('\nPerplexity : ', lda_model.log_perplexity(corpus)) 

# Compute Coherence Score
coherence_model_lda = CoherenceModel(model=lda_model, texts=data_lemmatized,corpus=corpus, dictionary=id2word, coherence='c_v')
coherence_lda = coherence_model_lda.get_coherence()
print('\nCoherence Score: ', coherence_lda)

# %% [markdown]
# need to work on
# 1)increasing the number of topics  and no. of words in each cloud  -tuning part
# 2)identifying the root word - Lemmatyzing, stemming
# usage of bi-grams & tri-grams
# 3)topic 3-pre-processing - reomval of names -Mohd,NORAINI,ABDULLAH,BINTI,
# 4)system, legal , stated , ABD
#
# doubt - number ,within, SDN BHD , Pvt. Ltd. , Berhad

# %% [markdown]
# ### Visualising Topics:

# %%
# pip install pyLDAvis

# %%
# pip install gensimvis

# %%
# Visualize the topics
# pyLDAvis.enable_notebook()
# vis = gensimvis.prepare(lda_model, corpus, id2word)
# vis

# %% [markdown]
# To measure how good is our model we can use **perplexity score** and **coherence socre**. The lower score of perplexity is better for the model.

# %%
df_all_comments

# %%
doc_lda = lda_model[corpus]
x=lda_model.print_topics()
y={}
for i,j in x:
    y[i]=j

# %%
df_all_comments["Topic"]=""
df_all_comments["All_Topic_Probabilities"]=""
df_all_comments["Topic No"]=""
for i, doc in enumerate(corpus):
      topic=sorted(lda_model.get_document_topics(doc),key=lambda x: x[1],reverse=True)[0][0]
      df_all_comments["Topic No"].loc[i]=topic  
      df_all_comments["Topic"].loc[i]=y[topic]
      df_all_comments["All_Topic_Probabilities"].loc[i]=lda_model.get_document_topics(doc)
#     .index(max(dict(lda_model.get_document_topics(doc)).values()))
#      y[topic]

# %%
df_all_comments["Topic words"]=df_all_comments["Topic No"].apply(lambda x: dict1[x])

# %%
# df_all_comments.to_csv("Output_of_topic_modelling.csv")
# len(corpus)
# df_all_comments.loc[221574:,["V_COMMENTS_2"]]

# %%
df_all_comments[df_all_comments["All_Topic_Probabilities"].apply(lambda x:type(x)==str )]["All_Topic_Probabilities"]
# model.get_document_topics(doc)

# %%
df_all_comments["Topic"].value_counts()

# %%
# df_all_comments[]

# %%
df_all_comments.to_csv("Output_of_topic_modelling_only_bow_bi_tri.csv")

# %%
# import pickle
# pickle.dump(lda_model,open("lda_model_l_bi_tri.sav","wb"))

# %%
# model = pickle.load(open("lda_model_lemmatizer_bi_gram.sav","rb"))
# import pickle
# model = pickle.load(open("lda_model.sav","rb"))

# %% [markdown]
# This notebook is mainly focused on LDA implementation for coherence score you can read this [medium article](https://towardsdatascience.com/evaluate-topic-model-in-python-latent-dirichlet-allocation-lda-7d57484bb5d0).

# %% [markdown]
# ### Using tf-idf for feature extraction

# %%
import pandas as pd
import numpy as np 
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
from gensim.models import TfidfModel

# %%
import numpy as np
tfidf = TfidfModel(corpus, smartirs='ntc')

# %%
print(tfidf[corpus][1])
tfidf_corpus=tfidf[corpus]
# corpus_example = [[(id2word[id], freq) for id, freq in cp] for cp in corpus[:2]]

# %%
df_all_comments["TFIDF_Feature"]=[doc for doc in tfidf_corpus]

# %%
df_all_comments

# %%
lda_tfidf_model = gensim.models.ldamodel.LdaModel(corpus=tfidf_corpus,
                                           id2word=id2word,
                                           num_topics=10, 
                                           random_state=100,
                                           update_every=1,
                                           chunksize=100,
                                           passes=10,
                                           alpha='symmetric',
                                           per_word_topics=True,
                                           eta = 0.6)

# %%
lda_tfidf_model

# %%
# Print the Keyword in the 10 topics
pprint(lda_tfidf_model.print_topics())
# doc_lda = lda_tfidf_model[corpus]

# %%
# get_document_topics(corpus)
for i, doc in enumerate(tfidf_corpus):
    print("Document", i+1)
    print(lda_tfidf_model.get_document_topics(doc))

# %%
import pickle
pickle.dump(lda_tfidf_model,open("lda_model_tfidf_lemmatizer_bi_tri.sav","wb"))

# %%
lda_tfidf_model1= pickle.load(open("lda_model_tfidf_lemmatizer_bi_tri.sav","rb"))

# %%
# Compute Perplexity
print('\nPerplexity : ', lda_tfidf_model1.log_perplexity(corpus)) 

# Compute Coherence Score
coherence_model_lda_tf_idf = CoherenceModel(model=lda_tfidf_model1, texts=data_lemmatized,corpus=tfidf_corpus, dictionary=id2word, coherence='c_v')
coherence_lda = coherence_model_lda_tf_idf.get_coherence()
print('\nCoherence Score: ', coherence_lda)
# Out:
# Perplexity :  -6.3597814349885216
#
# Coherence Score:  0.5853997278341578

# %%
top_words_per_topic = []
for topic_id in range(lda_tfidf_model.num_topics):
    top_words = [id2word[word_id] for word_id, prob in lda_tfidf_model1.get_topic_terms(topic_id, topn=15)]
    top_words_per_topic.append(top_words)

# %%
df_topics=pd.DataFrame({})

l=[]
for i in top_words_per_topic:
    l.append(i)

# %%
df_topics["Topics"]=l

# %%
df_topics.to_csv("Additional words in topics tf idf bi tri.csv")

# %%
df_topics
# Out:
#                                                                                                                                                                                                                                        Topics
# 0                                                                                                                             [dob, within, fall, range, possible, tool, discount, csc, cscdd, refer, comm, calculator, watch, trinity, date]
# 1  [perumda_bpr, karya_remaja, isis_west_africa, president, disrupted_air, yoinfo, attended_iswap_leadership_meete, yo, bombardment, ambassador, woman, identified_emir_kwalaram_te, incorporation, letak_jawatan, directors_perusahaan_umum]
# 2                                                                                                              [father, name, passport, native, comparison, edms, copy, make, character, difference, muhammad, document, official, link, uco]
# 3                                                                                                                                         [yob, year, birth, infer, bear, age, check, refinitiv, world, old, already, refer, per, yobage, vs]
# 4                                                                                                                                          [nric, date, birth, dob, number, d, i, watch, gcif, match, person, name, trinity, sallehuddin, as]
# 5                                                                     [imprisonment, sentence, fine, involvement_money_laundere, trafficking, involvement_money_laundering, account, bdt, arm, bdtm, life, active, transaction, arrest, apex]
# 6                                                                                                                        [name, son, host, mahani_dhter_dhter, sound, pep, full, similar, relate, spouse, per, profile, noor, base, location]
# 7                                                                                                 [relationship, news, deem, ago, relevant, non, material, incident, happen, business, bank, court, year, adverse, lared_proclaimed_offender]
# 8                                                                                                             [report, secretary, work, labourer, member, profile, occupation, unlikely, bhd, sdn, highly, malaysia, director, soe, ministry]
# 9                                            [code, place, negeri, member_gilgit_baltistan, didakwa, zakat, gbla, kementerian_pelajaran, perniagaan, trader, man, dan, province_pradesh, chairperson_association_wives, women_civil_servants]

# %%
dict2={}
for i,j in zip(range(len(top_words_per_topic)),top_words_per_topic):
    dict2[i]=j

# %% [markdown]
# This notebook is mainly focused on LDA implementation for coherence score you can read this [medium article](https://towardsdatascience.com/evaluate-topic-model-in-python-latent-dirichlet-allocation-lda-7d57484bb5d0).

# %%
# doc_lda = model[corpus]
x=lda_tfidf_model1.print_topics()
y={}
for i,j in x:
    y[i]=j

# %%
df_all_comments["Topic_tfidf_lda"]=""
df_all_comments["All_Topic_tfidf_Probabilities"]=""
df_all_comments["TF_tfidf_Topic_No"]=""
for i, doc in enumerate(corpus):
      topic=sorted(lda_tfidf_model1.get_document_topics(doc),key=lambda x: x[1],reverse=True)[0][0]
      df_all_comments["TF_tfidf_Topic_No"].loc[i]=topic  
      df_all_comments["Topic_tfidf_lda"].loc[i]=y[topic]
      df_all_comments["All_Topic_tfidf_Probabilities"].loc[i]=lda_tfidf_model1.get_document_topics(doc)
#     .index(max(dict(model.get_document_topics(doc)).values()))
#      y[topic]
# Out:
# C:\Users\local_00147515\Temp\1\ipykernel_10936\2659911435.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_all_comments["TF_tfidf_Topic_No"].loc[i]=topic
# C:\Users\local_00147515\Temp\1\ipykernel_10936\2659911435.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_all_comments["Topic_tfidf_lda"].loc[i]=y[topic]
# C:\Users\local_00147515\Temp\1\ipykernel_10936\2659911435.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_all_comments["All_Topic_tfidf_Probabilities"].loc[i]=lda_tfidf_model1.get_document_topics(doc)

# %%
df_all_comments[" TF IDF Topic words"]=df_all_comments["TF_tfidf_Topic_No"].apply(lambda x: dict2[x])

# %%
df_all_comments.to_csv("Output_of_topic_modelling_bow_tfidf_bi_tri.csv")

# %%
df_new=pd.read_csv("Output_of_topic_modelling_bow_tfidf_bi_tri.csv")

# %%
df_new.head()
df_new.drop("Unnamed: 0",axis=1,inplace=True)

# %%
df_new["Topic_tfidf_lda"].value_counts()
# Out:
# 0.013*"report" + 0.011*"secretary" + 0.010*"work" + 0.010*"labourer" + 0.010*"member" + 0.009*"profile" + 0.008*"occupation" + 0.008*"unlikely" + 0.008*"bhd" + 0.008*"sdn"                                                             77442
# 0.106*"yob" + 0.066*"year" + 0.043*"birth" + 0.036*"infer" + 0.032*"bear" + 0.029*"age" + 0.027*"check" + 0.027*"refinitiv" + 0.026*"world" + 0.025*"old"                                                                               41877
# 0.116*"nric" + 0.077*"date" + 0.053*"birth" + 0.035*"dob" + 0.034*"number" + 0.027*"d" + 0.027*"i" + 0.024*"watch" + 0.019*"gcif" + 0.016*"match"                                                                                       34262
# 0.024*"imprisonment" + 0.023*"sentence" + 0.022*"fine" + 0.015*"involvement_money_laundere" + 0.015*"trafficking" + 0.015*"involvement_money_laundering" + 0.014*"account" + 0.014*"bdt" + 0.014*"arm" + 0.014*"bdtm"                   29496
# 0.039*"father" + 0.034*"name" + 0.015*"passport" + 0.013*"native" + 0.012*"comparison" + 0.012*"edms" + 0.011*"copy" + 0.011*"make" + 0.010*"character" + 0.010*"difference"                                                            11626
# 0.039*"name" + 0.024*"son" + 0.022*"host" + 0.021*"mahani_dhter_dhter" + 0.018*"sound" + 0.018*"pep" + 0.017*"full" + 0.016*"similar" + 0.014*"relate" + 0.012*"spouse"                                                                 10224
# 0.013*"relationship" + 0.013*"news" + 0.012*"deem" + 0.012*"ago" + 0.012*"relevant" + 0.011*"non" + 0.011*"material" + 0.011*"incident" + 0.011*"happen" + 0.011*"business"                                                              9933
# 0.050*"dob" + 0.043*"within" + 0.025*"fall" + 0.024*"range" + 0.023*"possible" + 0.016*"tool" + 0.015*"discount" + 0.015*"csc" + 0.013*"cscdd" + 0.010*"refer"                                                                           6621
# 0.004*"code" + 0.004*"place" + 0.003*"negeri" + 0.002*"member_gilgit_baltistan" + 0.001*"didakwa" + 0.001*"zakat" + 0.001*"gbla" + 0.001*"kementerian_pelajaran" + 0.001*"perniagaan" + 0.001*"trader"                                     71
# 0.005*"perumda_bpr" + 0.004*"karya_remaja" + 0.002*"isis_west_africa" + 0.001*"president" + 0.001*"disrupted_air" + 0.001*"yoinfo" + 0.001*"attended_iswap_leadership_meete" + 0.001*"yo" + 0.001*"bombardment" + 0.001*"ambassador"       22
# Name: Topic_tfidf_lda, dtype: int64

# %%
# df_new["Topic"].apply(lambda x:pd.isna(x))

# %%
import ast
df_new["V_COMMENTS_2"]=df_new["V_COMMENTS_2"].apply(lambda x:"" if pd.isna(x) else x)
df_new["Tokens"]=df_new["Tokens"].apply(lambda x: ast.literal_eval(x))

# %%
df_new["Topic words"]=df_new["Topic words"].apply(lambda x: ast.literal_eval(x))

# %%
df_new["Topic No"].unique()

# %% [markdown]
# ### Tuning hyperparameters:
#
# We can try out different number of topics, different values of alpha and beta(eta) to increse the conharence score. High conherence score is good for our model.

# %%
def calculate_coherence_score(n, alpha, beta):
    lda_tfidf_model2 = gensim.models.ldamodel.LdaModel(corpus=tfidf_corpus,
                                           id2word=id2word,
                                           num_topics=n, 
                                           random_state=100,
                                           update_every=1,
                                           chunksize=100,
                                           passes=10,
                                           alpha=alpha,
                                           per_word_topics=True,
                                           eta = beta)
    

    
    # Compute Coherence Score
    coherence_model_lda_tf_idf = CoherenceModel(model=lda_tfidf_model2, texts=data_lemmatized,corpus=tfidf_corpus, dictionary=id2word, coherence='c_v')
    coherence_lda = coherence_model_lda_tf_idf.get_coherence()
    print('\nCoherence Score: ', coherence_lda)
    
    
    return (coherence_lda,lda_tfidf_model2)

# %%
#list containing various hyperparameters
no_of_topics = [15]
alpha_list = ['symmetric',0.3,0.5,0.7]
beta_list = ['auto',0.3,0.5,0.7]


for n in no_of_topics:
    for alpha in alpha_list:
        for beta in beta_list:
            coherence_score,model = calculate_coherence_score(n, alpha, beta)
            print(f"n : {n} ; alpha : {alpha} ; beta : {beta} ; Score : {coherence_score}")
            
            
        
            pickle.dump(model,open("lda_model_tfidf_lemmatizer_bi_tri"+str(n)+str(alpha)+str(beta)+".sav","wb"))

# %%
#list containing various hyperparameters
no_of_topics = [20]
alpha_list = ['symmetric',0.3,0.5,0.7]
beta_list = ['auto',0.3,0.5,0.7]


for n in no_of_topics:
    for alpha in alpha_list:
        for beta in beta_list:
            coherence_score,model = calculate_coherence_score(n, alpha, beta)
            print(f"n : {n} ; alpha : {alpha} ; beta : {beta} ; Score : {coherence_score}")
            
            
        
            pickle.dump(model,open("lda_model_tfidf_lemmatizer_bi_tri_20_"+str(n)+str(alpha)+str(beta)+".sav","wb"))

# %% [markdown]
# Final LDA Model :

# %%
alpha_list = [0.3]
beta_list = [0.3]
no_of_topics=[20]

for n in no_of_topics:
    for alpha in alpha_list:
        for beta in beta_list:
            coherence_score,model = calculate_coherence_score(n, alpha, beta)
            print(f"n : {n} ; alpha : {alpha} ; beta : {beta} ; Score : {coherence_score}")
            
            
        
            pickle.dump(model,open("lda_model_tfidf_lemmatizer_bi_tri"+str(n)+str(alpha)+str(beta)+".sav","wb"))
# Out:
# Coherence Score:  0.5568997974304138
# n : 20 ; alpha : 0.3 ; beta : 0.3 ; Score : 0.5568997974304138

# %%
# Visualize the topics
pyLDAvis.enable_notebook()
vis = gensimvis.prepare(lda_model, corpus, id2word)
vis

# %% [markdown]
# The highest coherence score is : 0.4962 for number of topics = 14  alpha = 0.3 and beta = auto

# %%
lda_tfidf_model = gensim.models.ldamodel.LdaModel(corpus=tfidf_corpus,
                                           id2word=id2word,
                                           num_topics=10, 
                                           random_state=100,
                                           update_every=1,
                                           chunksize=100,
                                           passes=10,
                                           alpha='symmetric',
                                           per_word_topics=True,
                                           eta = 0.6)
